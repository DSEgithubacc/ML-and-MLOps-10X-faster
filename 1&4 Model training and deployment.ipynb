# %%
import pandas as pd
from pycaret.classification import *
import os
from sklearn.metrics import average_precision_score
from sklearn.utils import shuffle
from utils import *
import mlflow

# %% [markdown]
# ### # Don't forget to run mlflow in terminal

# %% [markdown]
# mlflow server --backend-store-uri sqlite:///mlflow.db --default-artifact-root ./artifacts --host 0.0.0.0

# %%
mlflow.set_tracking_uri("http://localhost:5000")

# %%
df = pd.read_csv('data' + os.sep + 'creditcard.csv', encoding_errors='ignore', on_bad_lines='skip')

# %%
df.Class.value_counts()
# Out:
# 0.0    284283
# 1.0       492
# Name: Class, dtype: int64

# %%
df.Class.value_counts()
# Out:
# 0.0    284283
# 1.0       492
# Name: Class, dtype: int64

# %% [markdown]
# # Some undersampling - Drop random records with 0 targets in order to optimize the calculation time

# %%
df_train, df_test = get_raw_data()

# %%
df_train.target.value_counts()
# Out:
# 0.0    2471
# 1.0     328
# Name: target, dtype: int64

# %%
df_test.target.value_counts()
# Out:
# 0.0    1215
# 1.0     164
# Name: target, dtype: int64

# %%
df_train.columns
# Out:
# Index(['Time', 'V1', 'V2', 'V3', 'V4', 'V5', 'V6', 'V7', 'V8', 'V9', 'V10',
#        'V11', 'V12', 'V13', 'V14', 'V15', 'V16', 'V17', 'V18', 'V19', 'V20',
#        'V21', 'V22', 'V23', 'V24', 'V25', 'V26', 'V27', 'V28', 'Amount',
#        'target'],
#       dtype='object')

# %% [markdown]
# # Training different models with different data preprocessing

# %%
numeric_feature_list = df_train.columns[0:-1].to_list()

# %%
clf1 = setup(silent=True,
             data = df_train, 
             target = 'target',
             numeric_features=numeric_feature_list,
             log_experiment = True,
             use_gpu=True,
             experiment_name = 'baseline',            )

add_metric('apc', 'APC', average_precision_score, target = 'pred_proba')
best = compare_models(sort="APC")
# Out:
# <style type="text/css">
# #T_0d7fa th {
#   text-align: left;
# }
# #T_0d7fa_row0_col0, #T_0d7fa_row0_col3, #T_0d7fa_row0_col4, #T_0d7fa_row1_col0, #T_0d7fa_row1_col1, #T_0d7fa_row1_col2, #T_0d7fa_row1_col3, #T_0d7fa_row1_col5, #T_0d7fa_row1_col6, #T_0d7fa_row1_col7, #T_0d7fa_row1_col8, #T_0d7fa_row2_col0, #T_0d7fa_row2_col1, #T_0d7fa_row2_col2, #T_0d7fa_row2_col3, #T_0d7fa_row2_col4, #T_0d7fa_row2_col5, #T_0d7fa_row2_col6, #T_0d7fa_row2_col7, #T_0d7fa_row2_col8, #T_0d7fa_row3_col0, #T_0d7fa_row3_col1, #T_0d7fa_row3_col2, #T_0d7fa_row3_col4, #T_0d7fa_row3_col5, #T_0d7fa_row3_col6, #T_0d7fa_row3_col7, #T_0d7fa_row3_col8, #T_0d7fa_row4_col0, #T_0d7fa_row4_col1, #T_0d7fa_row4_col2, #T_0d7fa_row4_col3, #T_0d7fa_row4_col4, #T_0d7fa_row4_col5, #T_0d7fa_row4_col6, #T_0d7fa_row4_col7, #T_0d7fa_row4_col8, #T_0d7fa_row5_col0, #T_0d7fa_row5_col1, #T_0d7fa_row5_col2, #T_0d7fa_row5_col3, #T_0d7fa_row5_col4, #T_0d7fa_row5_col5, #T_0d7fa_row5_col6, #T_0d7fa_row5_col7, #T_0d7fa_row5_col8, #T_0d7fa_row6_col0, #T_0d7fa_row6_col1, #T_0d7fa_row6_col2, #T_0d7fa_row6_col3, #T_0d7fa_row6_col5, #T_0d7fa_row6_col6, #T_0d7fa_row6_col7, #T_0d7fa_row6_col8, #T_0d7fa_row7_col0, #T_0d7fa_row7_col1, #T_0d7fa_row7_col2, #T_0d7fa_row7_col3, #T_0d7fa_row7_col4, #T_0d7fa_row7_col5, #T_0d7fa_row7_col6, #T_0d7fa_row7_col7, #T_0d7fa_row7_col8, #T_0d7fa_row8_col0, #T_0d7fa_row8_col1, #T_0d7fa_row8_col2, #T_0d7fa_row8_col3, #T_0d7fa_row8_col5, #T_0d7fa_row8_col6, #T_0d7fa_row8_col7, #T_0d7fa_row8_col8, #T_0d7fa_row9_col0, #T_0d7fa_row9_col1, #T_0d7fa_row9_col2, #T_0d7fa_row9_col3, #T_0d7fa_row9_col4, #T_0d7fa_row9_col5, #T_0d7fa_row9_col6, #T_0d7fa_row9_col7, #T_0d7fa_row9_col8, #T_0d7fa_row10_col0, #T_0d7fa_row10_col1, #T_0d7fa_row10_col2, #T_0d7fa_row10_col3, #T_0d7fa_row10_col4, #T_0d7fa_row10_col5, #T_0d7fa_row10_col6, #T_0d7fa_row10_col7, #T_0d7fa_row10_col8, #T_0d7fa_row11_col0, #T_0d7fa_row11_col1, #T_0d7fa_row11_col2, #T_0d7fa_row11_col3, #T_0d7fa_row11_col4, #T_0d7fa_row11_col5, #T_0d7fa_row11_col6, #T_0d7fa_row11_col7, #T_0d7fa_row11_col8, #T_0d7fa_row12_col0, #T_0d7fa_row12_col1, #T_0d7fa_row12_col2, #T_0d7fa_row12_col3, #T_0d7fa_row12_col4, #T_0d7fa_row12_col5, #T_0d7fa_row12_col6, #T_0d7fa_row12_col7, #T_0d7fa_row12_col8, #T_0d7fa_row13_col0, #T_0d7fa_row13_col1, #T_0d7fa_row13_col2, #T_0d7fa_row13_col3, #T_0d7fa_row13_col4, #T_0d7fa_row13_col5, #T_0d7fa_row13_col6, #T_0d7fa_row13_col7, #T_0d7fa_row13_col8 {
#   text-align: left;
# }
# #T_0d7fa_row0_col1, #T_0d7fa_row0_col2, #T_0d7fa_row0_col5, #T_0d7fa_row0_col6, #T_0d7fa_row0_col7, #T_0d7fa_row0_col8, #T_0d7fa_row1_col4, #T_0d7fa_row3_col3, #T_0d7fa_row6_col4, #T_0d7fa_row8_col4 {
#   text-align: left;
#   background-color: yellow;
# }
# #T_0d7fa_row0_col9, #T_0d7fa_row1_col9, #T_0d7fa_row2_col9, #T_0d7fa_row3_col9, #T_0d7fa_row4_col9, #T_0d7fa_row5_col9, #T_0d7fa_row6_col9, #T_0d7fa_row7_col9, #T_0d7fa_row9_col9, #T_0d7fa_row10_col9, #T_0d7fa_row11_col9, #T_0d7fa_row12_col9, #T_0d7fa_row13_col9 {
#   text-align: left;
#   background-color: lightgrey;
# }
# #T_0d7fa_row8_col9 {
#   text-align: left;
#   background-color: yellow;
#   background-color: lightgrey;
# }
# </style>
# <table id="T_0d7fa">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_0d7fa_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_0d7fa_level0_col1" class="col_heading level0 col1" >Accuracy</th>
#       <th id="T_0d7fa_level0_col2" class="col_heading level0 col2" >AUC</th>
#       <th id="T_0d7fa_level0_col3" class="col_heading level0 col3" >Recall</th>
#       <th id="T_0d7fa_level0_col4" class="col_heading level0 col4" >Prec.</th>
#       <th id="T_0d7fa_level0_col5" class="col_heading level0 col5" >F1</th>
#       <th id="T_0d7fa_level0_col6" class="col_heading level0 col6" >Kappa</th>
#       <th id="T_0d7fa_level0_col7" class="col_heading level0 col7" >MCC</th>
#       <th id="T_0d7fa_level0_col8" class="col_heading level0 col8" >APC</th>
#       <th id="T_0d7fa_level0_col9" class="col_heading level0 col9" >TT (Sec)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_0d7fa_level0_row0" class="row_heading level0 row0" >lightgbm</th>
#       <td id="T_0d7fa_row0_col0" class="data row0 col0" >Light Gradient Boosting Machine</td>
#       <td id="T_0d7fa_row0_col1" class="data row0 col1" >0.9837</td>
#       <td id="T_0d7fa_row0_col2" class="data row0 col2" >0.9828</td>
#       <td id="T_0d7fa_row0_col3" class="data row0 col3" >0.8760</td>
#       <td id="T_0d7fa_row0_col4" class="data row0 col4" >0.9917</td>
#       <td id="T_0d7fa_row0_col5" class="data row0 col5" >0.9287</td>
#       <td id="T_0d7fa_row0_col6" class="data row0 col6" >0.9195</td>
#       <td id="T_0d7fa_row0_col7" class="data row0 col7" >0.9227</td>
#       <td id="T_0d7fa_row0_col8" class="data row0 col8" >0.9554</td>
#       <td id="T_0d7fa_row0_col9" class="data row0 col9" >4.4390</td>
#     </tr>
#     <tr>
#       <th id="T_0d7fa_level0_row1" class="row_heading level0 row1" >et</th>
#       <td id="T_0d7fa_row1_col0" class="data row1 col0" >Extra Trees Classifier</td>
#       <td id="T_0d7fa_row1_col1" class="data row1 col1" >0.9826</td>
#       <td id="T_0d7fa_row1_col2" class="data row1 col2" >0.9759</td>
#       <td id="T_0d7fa_row1_col3" class="data row1 col3" >0.8593</td>
#       <td id="T_0d7fa_row1_col4" class="data row1 col4" >1.0000</td>
#       <td id="T_0d7fa_row1_col5" class="data row1 col5" >0.9230</td>
#       <td id="T_0d7fa_row1_col6" class="data row1 col6" >0.9133</td>
#       <td id="T_0d7fa_row1_col7" class="data row1 col7" >0.9175</td>
#       <td id="T_0d7fa_row1_col8" class="data row1 col8" >0.9463</td>
#       <td id="T_0d7fa_row1_col9" class="data row1 col9" >1.1360</td>
#     </tr>
#     <tr>
#       <th id="T_0d7fa_level0_row2" class="row_heading level0 row2" >rf</th>
#       <td id="T_0d7fa_row2_col0" class="data row2 col0" >Random Forest Classifier</td>
#       <td id="T_0d7fa_row2_col1" class="data row2 col1" >0.9821</td>
#       <td id="T_0d7fa_row2_col2" class="data row2 col2" >0.9761</td>
#       <td id="T_0d7fa_row2_col3" class="data row2 col3" >0.8635</td>
#       <td id="T_0d7fa_row2_col4" class="data row2 col4" >0.9907</td>
#       <td id="T_0d7fa_row2_col5" class="data row2 col5" >0.9210</td>
#       <td id="T_0d7fa_row2_col6" class="data row2 col6" >0.9111</td>
#       <td id="T_0d7fa_row2_col7" class="data row2 col7" >0.9148</td>
#       <td id="T_0d7fa_row2_col8" class="data row2 col8" >0.9446</td>
#       <td id="T_0d7fa_row2_col9" class="data row2 col9" >0.9810</td>
#     </tr>
#     <tr>
#       <th id="T_0d7fa_level0_row3" class="row_heading level0 row3" >ada</th>
#       <td id="T_0d7fa_row3_col0" class="data row3 col0" >Ada Boost Classifier</td>
#       <td id="T_0d7fa_row3_col1" class="data row3 col1" >0.9801</td>
#       <td id="T_0d7fa_row3_col2" class="data row3 col2" >0.9686</td>
#       <td id="T_0d7fa_row3_col3" class="data row3 col3" >0.8843</td>
#       <td id="T_0d7fa_row3_col4" class="data row3 col4" >0.9526</td>
#       <td id="T_0d7fa_row3_col5" class="data row3 col5" >0.9155</td>
#       <td id="T_0d7fa_row3_col6" class="data row3 col6" >0.9042</td>
#       <td id="T_0d7fa_row3_col7" class="data row3 col7" >0.9061</td>
#       <td id="T_0d7fa_row3_col8" class="data row3 col8" >0.9461</td>
#       <td id="T_0d7fa_row3_col9" class="data row3 col9" >0.8600</td>
#     </tr>
#     <tr>
#       <th id="T_0d7fa_level0_row4" class="row_heading level0 row4" >gbc</th>
#       <td id="T_0d7fa_row4_col0" class="data row4 col0" >Gradient Boosting Classifier</td>
#       <td id="T_0d7fa_row4_col1" class="data row4 col1" >0.9796</td>
#       <td id="T_0d7fa_row4_col2" class="data row4 col2" >0.9748</td>
#       <td id="T_0d7fa_row4_col3" class="data row4 col3" >0.8717</td>
#       <td id="T_0d7fa_row4_col4" class="data row4 col4" >0.9588</td>
#       <td id="T_0d7fa_row4_col5" class="data row4 col5" >0.9117</td>
#       <td id="T_0d7fa_row4_col6" class="data row4 col6" >0.9002</td>
#       <td id="T_0d7fa_row4_col7" class="data row4 col7" >0.9024</td>
#       <td id="T_0d7fa_row4_col8" class="data row4 col8" >0.9488</td>
#       <td id="T_0d7fa_row4_co

# %% [markdown]
# # Fixing imbalance

# %%
clf1 = setup(silent=True,
             data = df_train, 
             target = 'target',
             numeric_features=numeric_feature_list,
             log_experiment = True,
             use_gpu=True,
             experiment_name = 'fixing imbalance',
             fix_imbalance = True, 
            )

add_metric('apc', 'APC', average_precision_score, target = 'pred_proba')
best = compare_models(sort="APC")
# Out:
# <style type="text/css">
# #T_1df0b th {
#   text-align: left;
# }
# #T_1df0b_row0_col0, #T_1df0b_row0_col3, #T_1df0b_row1_col0, #T_1df0b_row1_col1, #T_1df0b_row1_col2, #T_1df0b_row1_col3, #T_1df0b_row1_col4, #T_1df0b_row1_col5, #T_1df0b_row1_col6, #T_1df0b_row1_col7, #T_1df0b_row1_col8, #T_1df0b_row2_col0, #T_1df0b_row2_col1, #T_1df0b_row2_col2, #T_1df0b_row2_col3, #T_1df0b_row2_col4, #T_1df0b_row2_col5, #T_1df0b_row2_col6, #T_1df0b_row2_col7, #T_1df0b_row2_col8, #T_1df0b_row3_col0, #T_1df0b_row3_col1, #T_1df0b_row3_col2, #T_1df0b_row3_col3, #T_1df0b_row3_col4, #T_1df0b_row3_col5, #T_1df0b_row3_col6, #T_1df0b_row3_col7, #T_1df0b_row3_col8, #T_1df0b_row4_col0, #T_1df0b_row4_col1, #T_1df0b_row4_col2, #T_1df0b_row4_col3, #T_1df0b_row4_col4, #T_1df0b_row4_col5, #T_1df0b_row4_col6, #T_1df0b_row4_col7, #T_1df0b_row4_col8, #T_1df0b_row5_col0, #T_1df0b_row5_col1, #T_1df0b_row5_col2, #T_1df0b_row5_col3, #T_1df0b_row5_col4, #T_1df0b_row5_col5, #T_1df0b_row5_col6, #T_1df0b_row5_col7, #T_1df0b_row5_col8, #T_1df0b_row6_col0, #T_1df0b_row6_col1, #T_1df0b_row6_col2, #T_1df0b_row6_col3, #T_1df0b_row6_col4, #T_1df0b_row6_col5, #T_1df0b_row6_col6, #T_1df0b_row6_col7, #T_1df0b_row6_col8, #T_1df0b_row7_col0, #T_1df0b_row7_col1, #T_1df0b_row7_col2, #T_1df0b_row7_col3, #T_1df0b_row7_col4, #T_1df0b_row7_col5, #T_1df0b_row7_col6, #T_1df0b_row7_col7, #T_1df0b_row7_col8, #T_1df0b_row8_col0, #T_1df0b_row8_col1, #T_1df0b_row8_col2, #T_1df0b_row8_col3, #T_1df0b_row8_col4, #T_1df0b_row8_col5, #T_1df0b_row8_col6, #T_1df0b_row8_col7, #T_1df0b_row8_col8, #T_1df0b_row9_col0, #T_1df0b_row9_col1, #T_1df0b_row9_col2, #T_1df0b_row9_col3, #T_1df0b_row9_col4, #T_1df0b_row9_col5, #T_1df0b_row9_col6, #T_1df0b_row9_col7, #T_1df0b_row9_col8, #T_1df0b_row10_col0, #T_1df0b_row10_col1, #T_1df0b_row10_col2, #T_1df0b_row10_col3, #T_1df0b_row10_col4, #T_1df0b_row10_col5, #T_1df0b_row10_col6, #T_1df0b_row10_col7, #T_1df0b_row10_col8, #T_1df0b_row11_col0, #T_1df0b_row11_col1, #T_1df0b_row11_col2, #T_1df0b_row11_col3, #T_1df0b_row11_col4, #T_1df0b_row11_col5, #T_1df0b_row11_col6, #T_1df0b_row11_col7, #T_1df0b_row11_col8, #T_1df0b_row12_col0, #T_1df0b_row12_col1, #T_1df0b_row12_col2, #T_1df0b_row12_col4, #T_1df0b_row12_col5, #T_1df0b_row12_col6, #T_1df0b_row12_col7, #T_1df0b_row12_col8, #T_1df0b_row13_col0, #T_1df0b_row13_col1, #T_1df0b_row13_col2, #T_1df0b_row13_col3, #T_1df0b_row13_col4, #T_1df0b_row13_col5, #T_1df0b_row13_col6, #T_1df0b_row13_col7, #T_1df0b_row13_col8 {
#   text-align: left;
# }
# #T_1df0b_row0_col1, #T_1df0b_row0_col2, #T_1df0b_row0_col4, #T_1df0b_row0_col5, #T_1df0b_row0_col6, #T_1df0b_row0_col7, #T_1df0b_row0_col8, #T_1df0b_row12_col3 {
#   text-align: left;
#   background-color: yellow;
# }
# #T_1df0b_row0_col9, #T_1df0b_row1_col9, #T_1df0b_row2_col9, #T_1df0b_row3_col9, #T_1df0b_row4_col9, #T_1df0b_row5_col9, #T_1df0b_row6_col9, #T_1df0b_row7_col9, #T_1df0b_row8_col9, #T_1df0b_row9_col9, #T_1df0b_row10_col9, #T_1df0b_row12_col9, #T_1df0b_row13_col9 {
#   text-align: left;
#   background-color: lightgrey;
# }
# #T_1df0b_row11_col9 {
#   text-align: left;
#   background-color: yellow;
#   background-color: lightgrey;
# }
# </style>
# <table id="T_1df0b">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_1df0b_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_1df0b_level0_col1" class="col_heading level0 col1" >Accuracy</th>
#       <th id="T_1df0b_level0_col2" class="col_heading level0 col2" >AUC</th>
#       <th id="T_1df0b_level0_col3" class="col_heading level0 col3" >Recall</th>
#       <th id="T_1df0b_level0_col4" class="col_heading level0 col4" >Prec.</th>
#       <th id="T_1df0b_level0_col5" class="col_heading level0 col5" >F1</th>
#       <th id="T_1df0b_level0_col6" class="col_heading level0 col6" >Kappa</th>
#       <th id="T_1df0b_level0_col7" class="col_heading level0 col7" >MCC</th>
#       <th id="T_1df0b_level0_col8" class="col_heading level0 col8" >APC</th>
#       <th id="T_1df0b_level0_col9" class="col_heading level0 col9" >TT (Sec)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_1df0b_level0_row0" class="row_heading level0 row0" >et</th>
#       <td id="T_1df0b_row0_col0" class="data row0 col0" >Extra Trees Classifier</td>
#       <td id="T_1df0b_row0_col1" class="data row0 col1" >0.9821</td>
#       <td id="T_1df0b_row0_col2" class="data row0 col2" >0.9861</td>
#       <td id="T_1df0b_row0_col3" class="data row0 col3" >0.8730</td>
#       <td id="T_1df0b_row0_col4" class="data row0 col4" >0.9770</td>
#       <td id="T_1df0b_row0_col5" class="data row0 col5" >0.9216</td>
#       <td id="T_1df0b_row0_col6" class="data row0 col6" >0.9115</td>
#       <td id="T_1df0b_row0_col7" class="data row0 col7" >0.9137</td>
#       <td id="T_1df0b_row0_col8" class="data row0 col8" >0.9544</td>
#       <td id="T_1df0b_row0_col9" class="data row0 col9" >1.1190</td>
#     </tr>
#     <tr>
#       <th id="T_1df0b_level0_row1" class="row_heading level0 row1" >rf</th>
#       <td id="T_1df0b_row1_col0" class="data row1 col0" >Random Forest Classifier</td>
#       <td id="T_1df0b_row1_col1" class="data row1 col1" >0.9816</td>
#       <td id="T_1df0b_row1_col2" class="data row1 col2" >0.9806</td>
#       <td id="T_1df0b_row1_col3" class="data row1 col3" >0.8900</td>
#       <td id="T_1df0b_row1_col4" class="data row1 col4" >0.9567</td>
#       <td id="T_1df0b_row1_col5" class="data row1 col5" >0.9214</td>
#       <td id="T_1df0b_row1_col6" class="data row1 col6" >0.9110</td>
#       <td id="T_1df0b_row1_col7" class="data row1 col7" >0.9122</td>
#       <td id="T_1df0b_row1_col8" class="data row1 col8" >0.9538</td>
#       <td id="T_1df0b_row1_col9" class="data row1 col9" >1.2130</td>
#     </tr>
#     <tr>
#       <th id="T_1df0b_level0_row2" class="row_heading level0 row2" >gbc</th>
#       <td id="T_1df0b_row2_col0" class="data row2 col0" >Gradient Boosting Classifier</td>
#       <td id="T_1df0b_row2_col1" class="data row2 col1" >0.9801</td>
#       <td id="T_1df0b_row2_col2" class="data row2 col2" >0.9806</td>
#       <td id="T_1df0b_row2_col3" class="data row2 col3" >0.8944</td>
#       <td id="T_1df0b_row2_col4" class="data row2 col4" >0.9394</td>
#       <td id="T_1df0b_row2_col5" class="data row2 col5" >0.9156</td>
#       <td id="T_1df0b_row2_col6" class="data row2 col6" >0.9043</td>
#       <td id="T_1df0b_row2_col7" class="data row2 col7" >0.9051</td>
#       <td id="T_1df0b_row2_col8" class="data row2 col8" >0.9517</td>
#       <td id="T_1df0b_row2_col9" class="data row2 col9" >6.0420</td>
#     </tr>
#     <tr>
#       <th id="T_1df0b_level0_row3" class="row_heading level0 row3" >lightgbm</th>
#       <td id="T_1df0b_row3_col0" class="data row3 col0" >Light Gradient Boosting Machine</td>
#       <td id="T_1df0b_row3_col1" class="data row3 col1" >0.9816</td>
#       <td id="T_1df0b_row3_col2" class="data row3 col2" >0.9814</td>
#       <td id="T_1df0b_row3_col3" class="data row3 col3" >0.8774</td>
#       <td id="T_1df0b_row3_col4" class="data row3 col4" >0.9687</td>
#       <td id="T_1df0b_row3_col5" class="data row3 col5" >0.9201</td>
#       <td id="T_1df0b_row3_col6" class="data row3 col6" >0.9098</td>
#       <td id="T_1df0b_row3_col7" class="data row3 col7" >0.9116</td>
#       <td id="T_1df0b_row3_col8" class="data row3 col8" >0.9497</td>
#       <td id="T_1df0b_row3_col9" class="data row3 col9" >2.4510</td>
#     </tr>
#     <tr>
#       <th id="T_1df0b_level0_row4" class="row_heading level0 row4" >ada</th>
#       <td id="T_1df0b_row4_col0" class="data row4 col0" >Ada Boost Classifier</td>
#       <td id="T_1df0b_row4_col1" class="data row4 col1" >0.9801</td>
#       <td id="T_1df0b_row4_col2" class="data row4 col2" >0.9708</td>
#       <td id="T_1df0b_row4_col3" class="data row4 col3" >0.8984</td>
#       <td id="T_1df0b_row4_col4" class="data row4 col4" >0.9386</td>
#       <td id="T_1df0b_row4_col5" class="data row4 col5" >0.9172</td>
#       <td id="T_1df0b_row4_col6" class="data row4 col6" >0.9059</td>
#       <td id="T_1df0b_row4_col7" class="data row4 col7" >0.9067</td>
#       <td id="T_1df0b_row4_col8" class="data row4 col8" >0.9423</td>
#       <td id="T_1df0b_row4_co

# %% [markdown]
# # Removing outliers

# %%
clf1 = setup(data = df_train, 
             target = 'target', 
             numeric_features=numeric_feature_list,
             silent=True,
             log_experiment = True,
             use_gpu=True,
             experiment_name = 'removing outliers',
             remove_outliers = True
            )
add_metric('apc', 'APC', average_precision_score, target = 'pred_proba')
best = compare_models(sort="APC")
# Out:
# <style type="text/css">
# #T_fc018 th {
#   text-align: left;
# }
# #T_fc018_row0_col0, #T_fc018_row0_col1, #T_fc018_row0_col3, #T_fc018_row0_col5, #T_fc018_row0_col6, #T_fc018_row0_col7, #T_fc018_row1_col0, #T_fc018_row1_col2, #T_fc018_row1_col3, #T_fc018_row1_col4, #T_fc018_row1_col8, #T_fc018_row2_col0, #T_fc018_row2_col1, #T_fc018_row2_col2, #T_fc018_row2_col3, #T_fc018_row2_col4, #T_fc018_row2_col5, #T_fc018_row2_col6, #T_fc018_row2_col7, #T_fc018_row2_col8, #T_fc018_row3_col0, #T_fc018_row3_col1, #T_fc018_row3_col2, #T_fc018_row3_col3, #T_fc018_row3_col4, #T_fc018_row3_col5, #T_fc018_row3_col6, #T_fc018_row3_col7, #T_fc018_row3_col8, #T_fc018_row4_col0, #T_fc018_row4_col1, #T_fc018_row4_col2, #T_fc018_row4_col3, #T_fc018_row4_col4, #T_fc018_row4_col5, #T_fc018_row4_col6, #T_fc018_row4_col7, #T_fc018_row4_col8, #T_fc018_row5_col0, #T_fc018_row5_col1, #T_fc018_row5_col2, #T_fc018_row5_col3, #T_fc018_row5_col4, #T_fc018_row5_col5, #T_fc018_row5_col6, #T_fc018_row5_col7, #T_fc018_row5_col8, #T_fc018_row6_col0, #T_fc018_row6_col1, #T_fc018_row6_col2, #T_fc018_row6_col3, #T_fc018_row6_col4, #T_fc018_row6_col5, #T_fc018_row6_col6, #T_fc018_row6_col7, #T_fc018_row6_col8, #T_fc018_row7_col0, #T_fc018_row7_col1, #T_fc018_row7_col2, #T_fc018_row7_col3, #T_fc018_row7_col4, #T_fc018_row7_col5, #T_fc018_row7_col6, #T_fc018_row7_col7, #T_fc018_row7_col8, #T_fc018_row8_col0, #T_fc018_row8_col1, #T_fc018_row8_col2, #T_fc018_row8_col4, #T_fc018_row8_col5, #T_fc018_row8_col6, #T_fc018_row8_col7, #T_fc018_row8_col8, #T_fc018_row9_col0, #T_fc018_row9_col1, #T_fc018_row9_col2, #T_fc018_row9_col3, #T_fc018_row9_col4, #T_fc018_row9_col5, #T_fc018_row9_col6, #T_fc018_row9_col7, #T_fc018_row9_col8, #T_fc018_row10_col0, #T_fc018_row10_col1, #T_fc018_row10_col2, #T_fc018_row10_col3, #T_fc018_row10_col4, #T_fc018_row10_col5, #T_fc018_row10_col6, #T_fc018_row10_col7, #T_fc018_row10_col8, #T_fc018_row11_col0, #T_fc018_row11_col1, #T_fc018_row11_col2, #T_fc018_row11_col3, #T_fc018_row11_col4, #T_fc018_row11_col5, #T_fc018_row11_col6, #T_fc018_row11_col7, #T_fc018_row11_col8, #T_fc018_row12_col0, #T_fc018_row12_col1, #T_fc018_row12_col2, #T_fc018_row12_col3, #T_fc018_row12_col4, #T_fc018_row12_col5, #T_fc018_row12_col6, #T_fc018_row12_col7, #T_fc018_row12_col8, #T_fc018_row13_col0, #T_fc018_row13_col1, #T_fc018_row13_col2, #T_fc018_row13_col3, #T_fc018_row13_col5, #T_fc018_row13_col6, #T_fc018_row13_col7, #T_fc018_row13_col8 {
#   text-align: left;
# }
# #T_fc018_row0_col2, #T_fc018_row0_col4, #T_fc018_row0_col8, #T_fc018_row1_col1, #T_fc018_row1_col5, #T_fc018_row1_col6, #T_fc018_row1_col7, #T_fc018_row8_col3, #T_fc018_row13_col4 {
#   text-align: left;
#   background-color: yellow;
# }
# #T_fc018_row0_col9, #T_fc018_row1_col9, #T_fc018_row2_col9, #T_fc018_row3_col9, #T_fc018_row4_col9, #T_fc018_row5_col9, #T_fc018_row6_col9, #T_fc018_row7_col9, #T_fc018_row8_col9, #T_fc018_row9_col9, #T_fc018_row10_col9, #T_fc018_row12_col9, #T_fc018_row13_col9 {
#   text-align: left;
#   background-color: lightgrey;
# }
# #T_fc018_row11_col9 {
#   text-align: left;
#   background-color: yellow;
#   background-color: lightgrey;
# }
# </style>
# <table id="T_fc018">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_fc018_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_fc018_level0_col1" class="col_heading level0 col1" >Accuracy</th>
#       <th id="T_fc018_level0_col2" class="col_heading level0 col2" >AUC</th>
#       <th id="T_fc018_level0_col3" class="col_heading level0 col3" >Recall</th>
#       <th id="T_fc018_level0_col4" class="col_heading level0 col4" >Prec.</th>
#       <th id="T_fc018_level0_col5" class="col_heading level0 col5" >F1</th>
#       <th id="T_fc018_level0_col6" class="col_heading level0 col6" >Kappa</th>
#       <th id="T_fc018_level0_col7" class="col_heading level0 col7" >MCC</th>
#       <th id="T_fc018_level0_col8" class="col_heading level0 col8" >APC</th>
#       <th id="T_fc018_level0_col9" class="col_heading level0 col9" >TT (Sec)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_fc018_level0_row0" class="row_heading level0 row0" >lda</th>
#       <td id="T_fc018_row0_col0" class="data row0 col0" >Linear Discriminant Analysis</td>
#       <td id="T_fc018_row0_col1" class="data row0 col1" >0.9806</td>
#       <td id="T_fc018_row0_col2" class="data row0 col2" >0.9805</td>
#       <td id="T_fc018_row0_col3" class="data row0 col3" >0.7600</td>
#       <td id="T_fc018_row0_col4" class="data row0 col4" >1.0000</td>
#       <td id="T_fc018_row0_col5" class="data row0 col5" >0.8594</td>
#       <td id="T_fc018_row0_col6" class="data row0 col6" >0.8493</td>
#       <td id="T_fc018_row0_col7" class="data row0 col7" >0.8609</td>
#       <td id="T_fc018_row0_col8" class="data row0 col8" >0.9231</td>
#       <td id="T_fc018_row0_col9" class="data row0 col9" >0.0370</td>
#     </tr>
#     <tr>
#       <th id="T_fc018_level0_row1" class="row_heading level0 row1" >lightgbm</th>
#       <td id="T_fc018_row1_col0" class="data row1 col0" >Light Gradient Boosting Machine</td>
#       <td id="T_fc018_row1_col1" class="data row1 col1" >0.9833</td>
#       <td id="T_fc018_row1_col2" class="data row1 col2" >0.9714</td>
#       <td id="T_fc018_row1_col3" class="data row1 col3" >0.8067</td>
#       <td id="T_fc018_row1_col4" class="data row1 col4" >0.9862</td>
#       <td id="T_fc018_row1_col5" class="data row1 col5" >0.8834</td>
#       <td id="T_fc018_row1_col6" class="data row1 col6" >0.8746</td>
#       <td id="T_fc018_row1_col7" class="data row1 col7" >0.8820</td>
#       <td id="T_fc018_row1_col8" class="data row1 col8" >0.9191</td>
#       <td id="T_fc018_row1_col9" class="data row1 col9" >1.4560</td>
#     </tr>
#     <tr>
#       <th id="T_fc018_level0_row2" class="row_heading level0 row2" >et</th>
#       <td id="T_fc018_row2_col0" class="data row2 col0" >Extra Trees Classifier</td>
#       <td id="T_fc018_row2_col1" class="data row2 col1" >0.9828</td>
#       <td id="T_fc018_row2_col2" class="data row2 col2" >0.9736</td>
#       <td id="T_fc018_row2_col3" class="data row2 col3" >0.8000</td>
#       <td id="T_fc018_row2_col4" class="data row2 col4" >0.9866</td>
#       <td id="T_fc018_row2_col5" class="data row2 col5" >0.8792</td>
#       <td id="T_fc018_row2_col6" class="data row2 col6" >0.8701</td>
#       <td id="T_fc018_row2_col7" class="data row2 col7" >0.8781</td>
#       <td id="T_fc018_row2_col8" class="data row2 col8" >0.9186</td>
#       <td id="T_fc018_row2_col9" class="data row2 col9" >0.7430</td>
#     </tr>
#     <tr>
#       <th id="T_fc018_level0_row3" class="row_heading level0 row3" >rf</th>
#       <td id="T_fc018_row3_col0" class="data row3 col0" >Random Forest Classifier</td>
#       <td id="T_fc018_row3_col1" class="data row3 col1" >0.9828</td>
#       <td id="T_fc018_row3_col2" class="data row3 col2" >0.9638</td>
#       <td id="T_fc018_row3_col3" class="data row3 col3" >0.8067</td>
#       <td id="T_fc018_row3_col4" class="data row3 col4" >0.9783</td>
#       <td id="T_fc018_row3_col5" class="data row3 col5" >0.8809</td>
#       <td id="T_fc018_row3_col6" class="data row3 col6" >0.8718</td>
#       <td id="T_fc018_row3_col7" class="data row3 col7" >0.8784</td>
#       <td id="T_fc018_row3_col8" class="data row3 col8" >0.9037</td>
#       <td id="T_fc018_row3_col9" class="data row3 col9" >0.9380</td>
#     </tr>
#     <tr>
#       <th id="T_fc018_level0_row4" class="row_heading level0 row4" >ada</th>
#       <td id="T_fc018_row4_col0" class="data row4 col0" >Ada Boost Classifier</td>
#       <td id="T_fc018_row4_col1" class="data row4 col1" >0.9801</td>
#       <td id="T_fc018_row4_col2" class="data row4 col2" >0.9682</td>
#       <td id="T_fc018_row4_col3" class="data row4 col3" >0.8267</td>
#       <td id="T_fc018_row4_col4" class="data row4 col4" >0.9246</td>
#       <td id="T_fc018_row4_col5" class="data row4 col5" >0.8679</td>
#       <td id="T_fc018_row4_col6" class="data row4 col6" >0.8573</td>
#       <td id="T_fc018_row4_col7" class="data row4 col7" >0.8616</td>
#       <td id="T_fc018_row4_col8" class="data row4 col8" >0.9030</td>
#       <td id="T_fc018_row4_co

# %% [markdown]
# # Transformation

# %%
clf1 = setup(data = df_train, 
             target = 'target', 
             numeric_features=numeric_feature_list,
             silent=True,
             log_experiment = True,
             use_gpu=True,
             experiment_name = 'transformation',
             transformation = True, 
            )
add_metric('apc', 'APC', average_precision_score, target = 'pred_proba')
best = compare_models(sort="APC")
# Out:
# <style type="text/css">
# #T_597ed th {
#   text-align: left;
# }
# #T_597ed_row0_col0, #T_597ed_row0_col4, #T_597ed_row1_col0, #T_597ed_row1_col1, #T_597ed_row1_col2, #T_597ed_row1_col4, #T_597ed_row1_col5, #T_597ed_row1_col6, #T_597ed_row1_col7, #T_597ed_row1_col8, #T_597ed_row2_col0, #T_597ed_row2_col1, #T_597ed_row2_col2, #T_597ed_row2_col3, #T_597ed_row2_col5, #T_597ed_row2_col6, #T_597ed_row2_col7, #T_597ed_row2_col8, #T_597ed_row3_col0, #T_597ed_row3_col1, #T_597ed_row3_col2, #T_597ed_row3_col3, #T_597ed_row3_col4, #T_597ed_row3_col5, #T_597ed_row3_col6, #T_597ed_row3_col7, #T_597ed_row3_col8, #T_597ed_row4_col0, #T_597ed_row4_col1, #T_597ed_row4_col2, #T_597ed_row4_col3, #T_597ed_row4_col4, #T_597ed_row4_col5, #T_597ed_row4_col6, #T_597ed_row4_col7, #T_597ed_row4_col8, #T_597ed_row5_col0, #T_597ed_row5_col1, #T_597ed_row5_col2, #T_597ed_row5_col3, #T_597ed_row5_col4, #T_597ed_row5_col5, #T_597ed_row5_col6, #T_597ed_row5_col7, #T_597ed_row5_col8, #T_597ed_row6_col0, #T_597ed_row6_col1, #T_597ed_row6_col2, #T_597ed_row6_col3, #T_597ed_row6_col4, #T_597ed_row6_col5, #T_597ed_row6_col6, #T_597ed_row6_col7, #T_597ed_row6_col8, #T_597ed_row7_col0, #T_597ed_row7_col1, #T_597ed_row7_col2, #T_597ed_row7_col3, #T_597ed_row7_col4, #T_597ed_row7_col5, #T_597ed_row7_col6, #T_597ed_row7_col7, #T_597ed_row7_col8, #T_597ed_row8_col0, #T_597ed_row8_col1, #T_597ed_row8_col2, #T_597ed_row8_col3, #T_597ed_row8_col4, #T_597ed_row8_col5, #T_597ed_row8_col6, #T_597ed_row8_col7, #T_597ed_row8_col8, #T_597ed_row9_col0, #T_597ed_row9_col1, #T_597ed_row9_col2, #T_597ed_row9_col3, #T_597ed_row9_col4, #T_597ed_row9_col5, #T_597ed_row9_col6, #T_597ed_row9_col7, #T_597ed_row9_col8, #T_597ed_row10_col0, #T_597ed_row10_col1, #T_597ed_row10_col2, #T_597ed_row10_col3, #T_597ed_row10_col4, #T_597ed_row10_col5, #T_597ed_row10_col6, #T_597ed_row10_col7, #T_597ed_row10_col8, #T_597ed_row11_col0, #T_597ed_row11_col1, #T_597ed_row11_col2, #T_597ed_row11_col3, #T_597ed_row11_col4, #T_597ed_row11_col5, #T_597ed_row11_col6, #T_597ed_row11_col7, #T_597ed_row11_col8, #T_597ed_row12_col0, #T_597ed_row12_col1, #T_597ed_row12_col2, #T_597ed_row12_col3, #T_597ed_row12_col4, #T_597ed_row12_col5, #T_597ed_row12_col6, #T_597ed_row12_col7, #T_597ed_row12_col8, #T_597ed_row13_col0, #T_597ed_row13_col1, #T_597ed_row13_col2, #T_597ed_row13_col3, #T_597ed_row13_col4, #T_597ed_row13_col5, #T_597ed_row13_col6, #T_597ed_row13_col7, #T_597ed_row13_col8 {
#   text-align: left;
# }
# #T_597ed_row0_col1, #T_597ed_row0_col2, #T_597ed_row0_col3, #T_597ed_row0_col5, #T_597ed_row0_col6, #T_597ed_row0_col7, #T_597ed_row0_col8, #T_597ed_row1_col3, #T_597ed_row2_col4 {
#   text-align: left;
#   background-color: yellow;
# }
# #T_597ed_row0_col9, #T_597ed_row1_col9, #T_597ed_row2_col9, #T_597ed_row3_col9, #T_597ed_row4_col9, #T_597ed_row5_col9, #T_597ed_row6_col9, #T_597ed_row7_col9, #T_597ed_row8_col9, #T_597ed_row9_col9, #T_597ed_row10_col9, #T_597ed_row12_col9, #T_597ed_row13_col9 {
#   text-align: left;
#   background-color: lightgrey;
# }
# #T_597ed_row11_col9 {
#   text-align: left;
#   background-color: yellow;
#   background-color: lightgrey;
# }
# </style>
# <table id="T_597ed">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_597ed_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_597ed_level0_col1" class="col_heading level0 col1" >Accuracy</th>
#       <th id="T_597ed_level0_col2" class="col_heading level0 col2" >AUC</th>
#       <th id="T_597ed_level0_col3" class="col_heading level0 col3" >Recall</th>
#       <th id="T_597ed_level0_col4" class="col_heading level0 col4" >Prec.</th>
#       <th id="T_597ed_level0_col5" class="col_heading level0 col5" >F1</th>
#       <th id="T_597ed_level0_col6" class="col_heading level0 col6" >Kappa</th>
#       <th id="T_597ed_level0_col7" class="col_heading level0 col7" >MCC</th>
#       <th id="T_597ed_level0_col8" class="col_heading level0 col8" >APC</th>
#       <th id="T_597ed_level0_col9" class="col_heading level0 col9" >TT (Sec)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_597ed_level0_row0" class="row_heading level0 row0" >lightgbm</th>
#       <td id="T_597ed_row0_col0" class="data row0 col0" >Light Gradient Boosting Machine</td>
#       <td id="T_597ed_row0_col1" class="data row0 col1" >0.9847</td>
#       <td id="T_597ed_row0_col2" class="data row0 col2" >0.9822</td>
#       <td id="T_597ed_row0_col3" class="data row0 col3" >0.8797</td>
#       <td id="T_597ed_row0_col4" class="data row0 col4" >0.9792</td>
#       <td id="T_597ed_row0_col5" class="data row0 col5" >0.9256</td>
#       <td id="T_597ed_row0_col6" class="data row0 col6" >0.9172</td>
#       <td id="T_597ed_row0_col7" class="data row0 col7" >0.9195</td>
#       <td id="T_597ed_row0_col8" class="data row0 col8" >0.9503</td>
#       <td id="T_597ed_row0_col9" class="data row0 col9" >3.0360</td>
#     </tr>
#     <tr>
#       <th id="T_597ed_level0_row1" class="row_heading level0 row1" >lr</th>
#       <td id="T_597ed_row1_col0" class="data row1 col0" >Logistic Regression</td>
#       <td id="T_597ed_row1_col1" class="data row1 col1" >0.9816</td>
#       <td id="T_597ed_row1_col2" class="data row1 col2" >0.9812</td>
#       <td id="T_597ed_row1_col3" class="data row1 col3" >0.8797</td>
#       <td id="T_597ed_row1_col4" class="data row1 col4" >0.9536</td>
#       <td id="T_597ed_row1_col5" class="data row1 col5" >0.9125</td>
#       <td id="T_597ed_row1_col6" class="data row1 col6" >0.9023</td>
#       <td id="T_597ed_row1_col7" class="data row1 col7" >0.9048</td>
#       <td id="T_597ed_row1_col8" class="data row1 col8" >0.9455</td>
#       <td id="T_597ed_row1_col9" class="data row1 col9" >0.0580</td>
#     </tr>
#     <tr>
#       <th id="T_597ed_level0_row2" class="row_heading level0 row2" >et</th>
#       <td id="T_597ed_row2_col0" class="data row2 col0" >Extra Trees Classifier</td>
#       <td id="T_597ed_row2_col1" class="data row2 col1" >0.9842</td>
#       <td id="T_597ed_row2_col2" class="data row2 col2" >0.9816</td>
#       <td id="T_597ed_row2_col3" class="data row2 col3" >0.8613</td>
#       <td id="T_597ed_row2_col4" class="data row2 col4" >0.9952</td>
#       <td id="T_597ed_row2_col5" class="data row2 col5" >0.9222</td>
#       <td id="T_597ed_row2_col6" class="data row2 col6" >0.9135</td>
#       <td id="T_597ed_row2_col7" class="data row2 col7" >0.9171</td>
#       <td id="T_597ed_row2_col8" class="data row2 col8" >0.9447</td>
#       <td id="T_597ed_row2_col9" class="data row2 col9" >1.1230</td>
#     </tr>
#     <tr>
#       <th id="T_597ed_level0_row3" class="row_heading level0 row3" >lda</th>
#       <td id="T_597ed_row3_col0" class="data row3 col0" >Linear Discriminant Analysis</td>
#       <td id="T_597ed_row3_col1" class="data row3 col1" >0.9806</td>
#       <td id="T_597ed_row3_col2" class="data row3 col2" >0.9814</td>
#       <td id="T_597ed_row3_col3" class="data row3 col3" >0.8290</td>
#       <td id="T_597ed_row3_col4" class="data row3 col4" >0.9944</td>
#       <td id="T_597ed_row3_col5" class="data row3 col5" >0.9031</td>
#       <td id="T_597ed_row3_col6" class="data row3 col6" >0.8925</td>
#       <td id="T_597ed_row3_col7" class="data row3 col7" >0.8977</td>
#       <td id="T_597ed_row3_col8" class="data row3 col8" >0.9428</td>
#       <td id="T_597ed_row3_col9" class="data row3 col9" >0.0570</td>
#     </tr>
#     <tr>
#       <th id="T_597ed_level0_row4" class="row_heading level0 row4" >rf</th>
#       <td id="T_597ed_row4_col0" class="data row4 col0" >Random Forest Classifier</td>
#       <td id="T_597ed_row4_col1" class="data row4 col1" >0.9837</td>
#       <td id="T_597ed_row4_col2" class="data row4 col2" >0.9806</td>
#       <td id="T_597ed_row4_col3" class="data row4 col3" >0.8658</td>
#       <td id="T_597ed_row4_col4" class="data row4 col4" >0.9857</td>
#       <td id="T_597ed_row4_col5" class="data row4 col5" >0.9206</td>
#       <td id="T_597ed_row4_col6" class="data row4 col6" >0.9115</td>
#       <td id="T_597ed_row4_col7" class="data row4 col7" >0.9147</td>
#       <td id="T_597ed_row4_col8" class="data row4 col8" >0.9413</td>
#       <td id="T_597ed_row4_col9

# %% [markdown]
# # Feature interaction

# %%
clf1 = setup(data = df_train, 
             target = 'target',
             numeric_features=numeric_feature_list,
             silent=True,
             log_experiment = True,
             use_gpu=True,
             experiment_name = 'feature interaction', 
             feature_interaction = True, feature_ratio = True, 
            )
add_metric('apc', 'APC', average_precision_score, target = 'pred_proba')
best = compare_models(sort="APC")
# Out:
# <style type="text/css">
# #T_907c8 th {
#   text-align: left;
# }
# #T_907c8_row0_col0, #T_907c8_row0_col1, #T_907c8_row0_col3, #T_907c8_row0_col4, #T_907c8_row0_col5, #T_907c8_row0_col6, #T_907c8_row0_col7, #T_907c8_row1_col0, #T_907c8_row1_col1, #T_907c8_row1_col2, #T_907c8_row1_col3, #T_907c8_row1_col4, #T_907c8_row1_col5, #T_907c8_row1_col6, #T_907c8_row1_col7, #T_907c8_row1_col8, #T_907c8_row2_col0, #T_907c8_row2_col2, #T_907c8_row2_col3, #T_907c8_row2_col8, #T_907c8_row3_col0, #T_907c8_row3_col1, #T_907c8_row3_col2, #T_907c8_row3_col3, #T_907c8_row3_col4, #T_907c8_row3_col5, #T_907c8_row3_col6, #T_907c8_row3_col7, #T_907c8_row3_col8, #T_907c8_row4_col0, #T_907c8_row4_col1, #T_907c8_row4_col2, #T_907c8_row4_col3, #T_907c8_row4_col4, #T_907c8_row4_col5, #T_907c8_row4_col6, #T_907c8_row4_col7, #T_907c8_row4_col8, #T_907c8_row5_col0, #T_907c8_row5_col1, #T_907c8_row5_col2, #T_907c8_row5_col3, #T_907c8_row5_col4, #T_907c8_row5_col5, #T_907c8_row5_col6, #T_907c8_row5_col7, #T_907c8_row5_col8, #T_907c8_row6_col0, #T_907c8_row6_col1, #T_907c8_row6_col2, #T_907c8_row6_col3, #T_907c8_row6_col4, #T_907c8_row6_col5, #T_907c8_row6_col6, #T_907c8_row6_col7, #T_907c8_row6_col8, #T_907c8_row7_col0, #T_907c8_row7_col1, #T_907c8_row7_col2, #T_907c8_row7_col3, #T_907c8_row7_col4, #T_907c8_row7_col5, #T_907c8_row7_col6, #T_907c8_row7_col7, #T_907c8_row7_col8, #T_907c8_row8_col0, #T_907c8_row8_col1, #T_907c8_row8_col2, #T_907c8_row8_col3, #T_907c8_row8_col4, #T_907c8_row8_col5, #T_907c8_row8_col6, #T_907c8_row8_col7, #T_907c8_row8_col8, #T_907c8_row9_col0, #T_907c8_row9_col1, #T_907c8_row9_col2, #T_907c8_row9_col3, #T_907c8_row9_col4, #T_907c8_row9_col5, #T_907c8_row9_col6, #T_907c8_row9_col7, #T_907c8_row9_col8, #T_907c8_row10_col0, #T_907c8_row10_col1, #T_907c8_row10_col2, #T_907c8_row10_col3, #T_907c8_row10_col4, #T_907c8_row10_col5, #T_907c8_row10_col6, #T_907c8_row10_col7, #T_907c8_row10_col8, #T_907c8_row11_col0, #T_907c8_row11_col1, #T_907c8_row11_col2, #T_907c8_row11_col3, #T_907c8_row11_col4, #T_907c8_row11_col5, #T_907c8_row11_col6, #T_907c8_row11_col7, #T_907c8_row11_col8, #T_907c8_row12_col0, #T_907c8_row12_col1, #T_907c8_row12_col2, #T_907c8_row12_col4, #T_907c8_row12_col5, #T_907c8_row12_col6, #T_907c8_row12_col7, #T_907c8_row12_col8, #T_907c8_row13_col0, #T_907c8_row13_col1, #T_907c8_row13_col2, #T_907c8_row13_col3, #T_907c8_row13_col4, #T_907c8_row13_col5, #T_907c8_row13_col6, #T_907c8_row13_col7, #T_907c8_row13_col8 {
#   text-align: left;
# }
# #T_907c8_row0_col2, #T_907c8_row0_col8, #T_907c8_row2_col1, #T_907c8_row2_col4, #T_907c8_row2_col5, #T_907c8_row2_col6, #T_907c8_row2_col7, #T_907c8_row12_col3 {
#   text-align: left;
#   background-color: yellow;
# }
# #T_907c8_row0_col9, #T_907c8_row1_col9, #T_907c8_row2_col9, #T_907c8_row3_col9, #T_907c8_row4_col9, #T_907c8_row5_col9, #T_907c8_row6_col9, #T_907c8_row7_col9, #T_907c8_row8_col9, #T_907c8_row9_col9, #T_907c8_row10_col9, #T_907c8_row12_col9, #T_907c8_row13_col9 {
#   text-align: left;
#   background-color: lightgrey;
# }
# #T_907c8_row11_col9 {
#   text-align: left;
#   background-color: yellow;
#   background-color: lightgrey;
# }
# </style>
# <table id="T_907c8">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_907c8_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_907c8_level0_col1" class="col_heading level0 col1" >Accuracy</th>
#       <th id="T_907c8_level0_col2" class="col_heading level0 col2" >AUC</th>
#       <th id="T_907c8_level0_col3" class="col_heading level0 col3" >Recall</th>
#       <th id="T_907c8_level0_col4" class="col_heading level0 col4" >Prec.</th>
#       <th id="T_907c8_level0_col5" class="col_heading level0 col5" >F1</th>
#       <th id="T_907c8_level0_col6" class="col_heading level0 col6" >Kappa</th>
#       <th id="T_907c8_level0_col7" class="col_heading level0 col7" >MCC</th>
#       <th id="T_907c8_level0_col8" class="col_heading level0 col8" >APC</th>
#       <th id="T_907c8_level0_col9" class="col_heading level0 col9" >TT (Sec)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_907c8_level0_row0" class="row_heading level0 row0" >lightgbm</th>
#       <td id="T_907c8_row0_col0" class="data row0 col0" >Light Gradient Boosting Machine</td>
#       <td id="T_907c8_row0_col1" class="data row0 col1" >0.9811</td>
#       <td id="T_907c8_row0_col2" class="data row0 col2" >0.9880</td>
#       <td id="T_907c8_row0_col3" class="data row0 col3" >0.8677</td>
#       <td id="T_907c8_row0_col4" class="data row0 col4" >0.9608</td>
#       <td id="T_907c8_row0_col5" class="data row0 col5" >0.9094</td>
#       <td id="T_907c8_row0_col6" class="data row0 col6" >0.8990</td>
#       <td id="T_907c8_row0_col7" class="data row0 col7" >0.9019</td>
#       <td id="T_907c8_row0_col8" class="data row0 col8" >0.9555</td>
#       <td id="T_907c8_row0_col9" class="data row0 col9" >7.4350</td>
#     </tr>
#     <tr>
#       <th id="T_907c8_level0_row1" class="row_heading level0 row1" >gbc</th>
#       <td id="T_907c8_row1_col0" class="data row1 col0" >Gradient Boosting Classifier</td>
#       <td id="T_907c8_row1_col1" class="data row1 col1" >0.9760</td>
#       <td id="T_907c8_row1_col2" class="data row1 col2" >0.9859</td>
#       <td id="T_907c8_row1_col3" class="data row1 col3" >0.8677</td>
#       <td id="T_907c8_row1_col4" class="data row1 col4" >0.9177</td>
#       <td id="T_907c8_row1_col5" class="data row1 col5" >0.8889</td>
#       <td id="T_907c8_row1_col6" class="data row1 col6" >0.8756</td>
#       <td id="T_907c8_row1_col7" class="data row1 col7" >0.8779</td>
#       <td id="T_907c8_row1_col8" class="data row1 col8" >0.9525</td>
#       <td id="T_907c8_row1_col9" class="data row1 col9" >13.3570</td>
#     </tr>
#     <tr>
#       <th id="T_907c8_level0_row2" class="row_heading level0 row2" >et</th>
#       <td id="T_907c8_row2_col0" class="data row2 col0" >Extra Trees Classifier</td>
#       <td id="T_907c8_row2_col1" class="data row2 col1" >0.9821</td>
#       <td id="T_907c8_row2_col2" class="data row2 col2" >0.9798</td>
#       <td id="T_907c8_row2_col3" class="data row2 col3" >0.8630</td>
#       <td id="T_907c8_row2_col4" class="data row2 col4" >0.9763</td>
#       <td id="T_907c8_row2_col5" class="data row2 col5" >0.9133</td>
#       <td id="T_907c8_row2_col6" class="data row2 col6" >0.9035</td>
#       <td id="T_907c8_row2_col7" class="data row2 col7" >0.9073</td>
#       <td id="T_907c8_row2_col8" class="data row2 col8" >0.9484</td>
#       <td id="T_907c8_row2_col9" class="data row2 col9" >2.1320</td>
#     </tr>
#     <tr>
#       <th id="T_907c8_level0_row3" class="row_heading level0 row3" >rf</th>
#       <td id="T_907c8_row3_col0" class="data row3 col0" >Random Forest Classifier</td>
#       <td id="T_907c8_row3_col1" class="data row3 col1" >0.9816</td>
#       <td id="T_907c8_row3_col2" class="data row3 col2" >0.9787</td>
#       <td id="T_907c8_row3_col3" class="data row3 col3" >0.8630</td>
#       <td id="T_907c8_row3_col4" class="data row3 col4" >0.9706</td>
#       <td id="T_907c8_row3_col5" class="data row3 col5" >0.9109</td>
#       <td id="T_907c8_row3_col6" class="data row3 col6" >0.9008</td>
#       <td id="T_907c8_row3_col7" class="data row3 col7" >0.9043</td>
#       <td id="T_907c8_row3_col8" class="data row3 col8" >0.9450</td>
#       <td id="T_907c8_row3_col9" class="data row3 col9" >1.9620</td>
#     </tr>
#     <tr>
#       <th id="T_907c8_level0_row4" class="row_heading level0 row4" >ada</th>
#       <td id="T_907c8_row4_col0" class="data row4 col0" >Ada Boost Classifier</td>
#       <td id="T_907c8_row4_col1" class="data row4 col1" >0.9781</td>
#       <td id="T_907c8_row4_col2" class="data row4 col2" >0.9718</td>
#       <td id="T_907c8_row4_col3" class="data row4 col3" >0.8677</td>
#       <td id="T_907c8_row4_col4" class="data row4 col4" >0.9325</td>
#       <td id="T_907c8_row4_col5" class="data row4 col5" >0.8975</td>
#       <td id="T_907c8_row4_col6" class="data row4 col6" >0.8852</td>
#       <td id="T_907c8_row4_col7" class="data row4 col7" >0.8868</td>
#       <td id="T_907c8_row4_col8" class="data row4 col8" >0.9388</td>
#       <td id="T_907c8_row4_c

# %% [markdown]
# # Polynomial features

# %%
clf1 = setup(data = df_train, 
             target = 'target', 
             numeric_features=numeric_feature_list,
             silent=True,
             log_experiment = True,
             use_gpu=True,
             experiment_name = 'polynomial features',
             polynomial_features = True,
            )
add_metric('apc', 'APC', average_precision_score, target = 'pred_proba')
best = compare_models(sort="APC")
# Out:
# <style type="text/css">
# #T_e6a08 th {
#   text-align: left;
# }
# #T_e6a08_row0_col0, #T_e6a08_row0_col1, #T_e6a08_row0_col2, #T_e6a08_row0_col3, #T_e6a08_row0_col4, #T_e6a08_row0_col5, #T_e6a08_row0_col6, #T_e6a08_row0_col7, #T_e6a08_row1_col0, #T_e6a08_row1_col1, #T_e6a08_row1_col2, #T_e6a08_row1_col3, #T_e6a08_row1_col4, #T_e6a08_row1_col5, #T_e6a08_row1_col6, #T_e6a08_row1_col7, #T_e6a08_row1_col8, #T_e6a08_row2_col0, #T_e6a08_row2_col3, #T_e6a08_row2_col4, #T_e6a08_row2_col8, #T_e6a08_row3_col0, #T_e6a08_row3_col2, #T_e6a08_row3_col3, #T_e6a08_row3_col4, #T_e6a08_row3_col5, #T_e6a08_row3_col6, #T_e6a08_row3_col7, #T_e6a08_row3_col8, #T_e6a08_row4_col0, #T_e6a08_row4_col1, #T_e6a08_row4_col2, #T_e6a08_row4_col3, #T_e6a08_row4_col4, #T_e6a08_row4_col5, #T_e6a08_row4_col6, #T_e6a08_row4_col7, #T_e6a08_row4_col8, #T_e6a08_row5_col0, #T_e6a08_row5_col1, #T_e6a08_row5_col2, #T_e6a08_row5_col3, #T_e6a08_row5_col4, #T_e6a08_row5_col5, #T_e6a08_row5_col6, #T_e6a08_row5_col7, #T_e6a08_row5_col8, #T_e6a08_row6_col0, #T_e6a08_row6_col1, #T_e6a08_row6_col2, #T_e6a08_row6_col3, #T_e6a08_row6_col4, #T_e6a08_row6_col5, #T_e6a08_row6_col6, #T_e6a08_row6_col7, #T_e6a08_row6_col8, #T_e6a08_row7_col0, #T_e6a08_row7_col1, #T_e6a08_row7_col2, #T_e6a08_row7_col3, #T_e6a08_row7_col4, #T_e6a08_row7_col5, #T_e6a08_row7_col6, #T_e6a08_row7_col7, #T_e6a08_row7_col8, #T_e6a08_row8_col0, #T_e6a08_row8_col1, #T_e6a08_row8_col2, #T_e6a08_row8_col4, #T_e6a08_row8_col5, #T_e6a08_row8_col6, #T_e6a08_row8_col7, #T_e6a08_row8_col8, #T_e6a08_row9_col0, #T_e6a08_row9_col1, #T_e6a08_row9_col2, #T_e6a08_row9_col3, #T_e6a08_row9_col4, #T_e6a08_row9_col5, #T_e6a08_row9_col6, #T_e6a08_row9_col7, #T_e6a08_row9_col8, #T_e6a08_row10_col0, #T_e6a08_row10_col1, #T_e6a08_row10_col2, #T_e6a08_row10_col3, #T_e6a08_row10_col4, #T_e6a08_row10_col5, #T_e6a08_row10_col6, #T_e6a08_row10_col7, #T_e6a08_row10_col8, #T_e6a08_row11_col0, #T_e6a08_row11_col1, #T_e6a08_row11_col2, #T_e6a08_row11_col3, #T_e6a08_row11_col4, #T_e6a08_row11_col5, #T_e6a08_row11_col6, #T_e6a08_row11_col7, #T_e6a08_row11_col8, #T_e6a08_row12_col0, #T_e6a08_row12_col1, #T_e6a08_row12_col2, #T_e6a08_row12_col3, #T_e6a08_row12_col4, #T_e6a08_row12_col5, #T_e6a08_row12_col6, #T_e6a08_row12_col7, #T_e6a08_row12_col8, #T_e6a08_row13_col0, #T_e6a08_row13_col1, #T_e6a08_row13_col2, #T_e6a08_row13_col3, #T_e6a08_row13_col5, #T_e6a08_row13_col6, #T_e6a08_row13_col7, #T_e6a08_row13_col8 {
#   text-align: left;
# }
# #T_e6a08_row0_col8, #T_e6a08_row2_col1, #T_e6a08_row2_col2, #T_e6a08_row2_col5, #T_e6a08_row2_col6, #T_e6a08_row2_col7, #T_e6a08_row3_col1, #T_e6a08_row8_col3, #T_e6a08_row13_col4 {
#   text-align: left;
#   background-color: yellow;
# }
# #T_e6a08_row0_col9, #T_e6a08_row1_col9, #T_e6a08_row2_col9, #T_e6a08_row3_col9, #T_e6a08_row4_col9, #T_e6a08_row5_col9, #T_e6a08_row6_col9, #T_e6a08_row7_col9, #T_e6a08_row8_col9, #T_e6a08_row9_col9, #T_e6a08_row10_col9, #T_e6a08_row12_col9, #T_e6a08_row13_col9 {
#   text-align: left;
#   background-color: lightgrey;
# }
# #T_e6a08_row11_col9 {
#   text-align: left;
#   background-color: yellow;
#   background-color: lightgrey;
# }
# </style>
# <table id="T_e6a08">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_e6a08_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_e6a08_level0_col1" class="col_heading level0 col1" >Accuracy</th>
#       <th id="T_e6a08_level0_col2" class="col_heading level0 col2" >AUC</th>
#       <th id="T_e6a08_level0_col3" class="col_heading level0 col3" >Recall</th>
#       <th id="T_e6a08_level0_col4" class="col_heading level0 col4" >Prec.</th>
#       <th id="T_e6a08_level0_col5" class="col_heading level0 col5" >F1</th>
#       <th id="T_e6a08_level0_col6" class="col_heading level0 col6" >Kappa</th>
#       <th id="T_e6a08_level0_col7" class="col_heading level0 col7" >MCC</th>
#       <th id="T_e6a08_level0_col8" class="col_heading level0 col8" >APC</th>
#       <th id="T_e6a08_level0_col9" class="col_heading level0 col9" >TT (Sec)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_e6a08_level0_row0" class="row_heading level0 row0" >lda</th>
#       <td id="T_e6a08_row0_col0" class="data row0 col0" >Linear Discriminant Analysis</td>
#       <td id="T_e6a08_row0_col1" class="data row0 col1" >0.9780</td>
#       <td id="T_e6a08_row0_col2" class="data row0 col2" >0.9794</td>
#       <td id="T_e6a08_row0_col3" class="data row0 col3" >0.8194</td>
#       <td id="T_e6a08_row0_col4" class="data row0 col4" >0.9897</td>
#       <td id="T_e6a08_row0_col5" class="data row0 col5" >0.8937</td>
#       <td id="T_e6a08_row0_col6" class="data row0 col6" >0.8817</td>
#       <td id="T_e6a08_row0_col7" class="data row0 col7" >0.8882</td>
#       <td id="T_e6a08_row0_col8" class="data row0 col8" >0.9519</td>
#       <td id="T_e6a08_row0_col9" class="data row0 col9" >0.0950</td>
#     </tr>
#     <tr>
#       <th id="T_e6a08_level0_row1" class="row_heading level0 row1" >gbc</th>
#       <td id="T_e6a08_row1_col0" class="data row1 col0" >Gradient Boosting Classifier</td>
#       <td id="T_e6a08_row1_col1" class="data row1 col1" >0.9816</td>
#       <td id="T_e6a08_row1_col2" class="data row1 col2" >0.9809</td>
#       <td id="T_e6a08_row1_col3" class="data row1 col3" >0.8810</td>
#       <td id="T_e6a08_row1_col4" class="data row1 col4" >0.9588</td>
#       <td id="T_e6a08_row1_col5" class="data row1 col5" >0.9169</td>
#       <td id="T_e6a08_row1_col6" class="data row1 col6" >0.9066</td>
#       <td id="T_e6a08_row1_col7" class="data row1 col7" >0.9085</td>
#       <td id="T_e6a08_row1_col8" class="data row1 col8" >0.9505</td>
#       <td id="T_e6a08_row1_col9" class="data row1 col9" >4.5400</td>
#     </tr>
#     <tr>
#       <th id="T_e6a08_level0_row2" class="row_heading level0 row2" >lightgbm</th>
#       <td id="T_e6a08_row2_col0" class="data row2 col0" >Light Gradient Boosting Machine</td>
#       <td id="T_e6a08_row2_col1" class="data row2 col1" >0.9821</td>
#       <td id="T_e6a08_row2_col2" class="data row2 col2" >0.9847</td>
#       <td id="T_e6a08_row2_col3" class="data row2 col3" >0.8723</td>
#       <td id="T_e6a08_row2_col4" class="data row2 col4" >0.9721</td>
#       <td id="T_e6a08_row2_col5" class="data row2 col5" >0.9185</td>
#       <td id="T_e6a08_row2_col6" class="data row2 col6" >0.9086</td>
#       <td id="T_e6a08_row2_col7" class="data row2 col7" >0.9108</td>
#       <td id="T_e6a08_row2_col8" class="data row2 col8" >0.9495</td>
#       <td id="T_e6a08_row2_col9" class="data row2 col9" >3.0850</td>
#     </tr>
#     <tr>
#       <th id="T_e6a08_level0_row3" class="row_heading level0 row3" >et</th>
#       <td id="T_e6a08_row3_col0" class="data row3 col0" >Extra Trees Classifier</td>
#       <td id="T_e6a08_row3_col1" class="data row3 col1" >0.9821</td>
#       <td id="T_e6a08_row3_col2" class="data row3 col2" >0.9725</td>
#       <td id="T_e6a08_row3_col3" class="data row3 col3" >0.8680</td>
#       <td id="T_e6a08_row3_col4" class="data row3 col4" >0.9759</td>
#       <td id="T_e6a08_row3_col5" class="data row3 col5" >0.9179</td>
#       <td id="T_e6a08_row3_col6" class="data row3 col6" >0.9080</td>
#       <td id="T_e6a08_row3_col7" class="data row3 col7" >0.9104</td>
#       <td id="T_e6a08_row3_col8" class="data row3 col8" >0.9449</td>
#       <td id="T_e6a08_row3_col9" class="data row3 col9" >1.1650</td>
#     </tr>
#     <tr>
#       <th id="T_e6a08_level0_row4" class="row_heading level0 row4" >rf</th>
#       <td id="T_e6a08_row4_col0" class="data row4 col0" >Random Forest Classifier</td>
#       <td id="T_e6a08_row4_col1" class="data row4 col1" >0.9816</td>
#       <td id="T_e6a08_row4_col2" class="data row4 col2" >0.9691</td>
#       <td id="T_e6a08_row4_col3" class="data row4 col3" >0.8723</td>
#       <td id="T_e6a08_row4_col4" class="data row4 col4" >0.9681</td>
#       <td id="T_e6a08_row4_col5" class="data row4 col5" >0.9164</td>
#       <td id="T_e6a08_row4_col6" class="data row4 col6" >0.9061</td>
#       <td id="T_e6a08_row4_col7" class="data row4 col7" >0.9085</td>
#       <td id="T_e6a08_row4_col8" class="data row4 col8" >0.9393</td>
#       <td id="T_e6a08

# %% [markdown]
# # Feature selection

# %%
clf1 = setup(data = df_train, 
             target = 'target',
             numeric_features=numeric_feature_list,
             silent=True,
             log_experiment = True,
             use_gpu=True,
             experiment_name = 'feature selection',
             feature_selection = True, feature_selection_threshold = 0.5,
            )
add_metric('apc', 'APC', average_precision_score, target = 'pred_proba')
best = compare_models(sort="APC")
# Out:
# <style type="text/css">
# #T_19dd9 th {
#   text-align: left;
# }
# #T_19dd9_row0_col0, #T_19dd9_row0_col1, #T_19dd9_row0_col3, #T_19dd9_row0_col4, #T_19dd9_row0_col5, #T_19dd9_row0_col6, #T_19dd9_row0_col7, #T_19dd9_row1_col0, #T_19dd9_row1_col2, #T_19dd9_row1_col3, #T_19dd9_row1_col4, #T_19dd9_row1_col7, #T_19dd9_row1_col8, #T_19dd9_row2_col0, #T_19dd9_row2_col2, #T_19dd9_row2_col3, #T_19dd9_row2_col4, #T_19dd9_row2_col5, #T_19dd9_row2_col6, #T_19dd9_row2_col8, #T_19dd9_row3_col0, #T_19dd9_row3_col2, #T_19dd9_row3_col3, #T_19dd9_row3_col4, #T_19dd9_row3_col7, #T_19dd9_row3_col8, #T_19dd9_row4_col0, #T_19dd9_row4_col1, #T_19dd9_row4_col2, #T_19dd9_row4_col3, #T_19dd9_row4_col4, #T_19dd9_row4_col5, #T_19dd9_row4_col6, #T_19dd9_row4_col7, #T_19dd9_row4_col8, #T_19dd9_row5_col0, #T_19dd9_row5_col1, #T_19dd9_row5_col2, #T_19dd9_row5_col3, #T_19dd9_row5_col4, #T_19dd9_row5_col5, #T_19dd9_row5_col6, #T_19dd9_row5_col7, #T_19dd9_row5_col8, #T_19dd9_row6_col0, #T_19dd9_row6_col1, #T_19dd9_row6_col2, #T_19dd9_row6_col3, #T_19dd9_row6_col4, #T_19dd9_row6_col5, #T_19dd9_row6_col6, #T_19dd9_row6_col7, #T_19dd9_row6_col8, #T_19dd9_row7_col0, #T_19dd9_row7_col1, #T_19dd9_row7_col2, #T_19dd9_row7_col3, #T_19dd9_row7_col4, #T_19dd9_row7_col5, #T_19dd9_row7_col6, #T_19dd9_row7_col7, #T_19dd9_row7_col8, #T_19dd9_row8_col0, #T_19dd9_row8_col1, #T_19dd9_row8_col2, #T_19dd9_row8_col4, #T_19dd9_row8_col5, #T_19dd9_row8_col6, #T_19dd9_row8_col7, #T_19dd9_row8_col8, #T_19dd9_row9_col0, #T_19dd9_row9_col1, #T_19dd9_row9_col2, #T_19dd9_row9_col3, #T_19dd9_row9_col4, #T_19dd9_row9_col5, #T_19dd9_row9_col6, #T_19dd9_row9_col7, #T_19dd9_row9_col8, #T_19dd9_row10_col0, #T_19dd9_row10_col1, #T_19dd9_row10_col2, #T_19dd9_row10_col3, #T_19dd9_row10_col4, #T_19dd9_row10_col5, #T_19dd9_row10_col6, #T_19dd9_row10_col7, #T_19dd9_row10_col8, #T_19dd9_row11_col0, #T_19dd9_row11_col1, #T_19dd9_row11_col2, #T_19dd9_row11_col3, #T_19dd9_row11_col4, #T_19dd9_row11_col5, #T_19dd9_row11_col6, #T_19dd9_row11_col7, #T_19dd9_row11_col8, #T_19dd9_row12_col0, #T_19dd9_row12_col1, #T_19dd9_row12_col2, #T_19dd9_row12_col3, #T_19dd9_row12_col4, #T_19dd9_row12_col5, #T_19dd9_row12_col6, #T_19dd9_row12_col7, #T_19dd9_row12_col8, #T_19dd9_row13_col0, #T_19dd9_row13_col1, #T_19dd9_row13_col2, #T_19dd9_row13_col3, #T_19dd9_row13_col5, #T_19dd9_row13_col6, #T_19dd9_row13_col7, #T_19dd9_row13_col8 {
#   text-align: left;
# }
# #T_19dd9_row0_col2, #T_19dd9_row0_col8, #T_19dd9_row1_col1, #T_19dd9_row1_col5, #T_19dd9_row1_col6, #T_19dd9_row2_col1, #T_19dd9_row2_col7, #T_19dd9_row3_col1, #T_19dd9_row3_col5, #T_19dd9_row3_col6, #T_19dd9_row8_col3, #T_19dd9_row13_col4 {
#   text-align: left;
#   background-color: yellow;
# }
# #T_19dd9_row0_col9, #T_19dd9_row1_col9, #T_19dd9_row2_col9, #T_19dd9_row3_col9, #T_19dd9_row4_col9, #T_19dd9_row5_col9, #T_19dd9_row6_col9, #T_19dd9_row7_col9, #T_19dd9_row8_col9, #T_19dd9_row9_col9, #T_19dd9_row10_col9, #T_19dd9_row12_col9, #T_19dd9_row13_col9 {
#   text-align: left;
#   background-color: lightgrey;
# }
# #T_19dd9_row11_col9 {
#   text-align: left;
#   background-color: yellow;
#   background-color: lightgrey;
# }
# </style>
# <table id="T_19dd9">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_19dd9_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_19dd9_level0_col1" class="col_heading level0 col1" >Accuracy</th>
#       <th id="T_19dd9_level0_col2" class="col_heading level0 col2" >AUC</th>
#       <th id="T_19dd9_level0_col3" class="col_heading level0 col3" >Recall</th>
#       <th id="T_19dd9_level0_col4" class="col_heading level0 col4" >Prec.</th>
#       <th id="T_19dd9_level0_col5" class="col_heading level0 col5" >F1</th>
#       <th id="T_19dd9_level0_col6" class="col_heading level0 col6" >Kappa</th>
#       <th id="T_19dd9_level0_col7" class="col_heading level0 col7" >MCC</th>
#       <th id="T_19dd9_level0_col8" class="col_heading level0 col8" >APC</th>
#       <th id="T_19dd9_level0_col9" class="col_heading level0 col9" >TT (Sec)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_19dd9_level0_row0" class="row_heading level0 row0" >gbc</th>
#       <td id="T_19dd9_row0_col0" class="data row0 col0" >Gradient Boosting Classifier</td>
#       <td id="T_19dd9_row0_col1" class="data row0 col1" >0.9745</td>
#       <td id="T_19dd9_row0_col2" class="data row0 col2" >0.9807</td>
#       <td id="T_19dd9_row0_col3" class="data row0 col3" >0.8379</td>
#       <td id="T_19dd9_row0_col4" class="data row0 col4" >0.9393</td>
#       <td id="T_19dd9_row0_col5" class="data row0 col5" >0.8829</td>
#       <td id="T_19dd9_row0_col6" class="data row0 col6" >0.8687</td>
#       <td id="T_19dd9_row0_col7" class="data row0 col7" >0.8722</td>
#       <td id="T_19dd9_row0_col8" class="data row0 col8" >0.9483</td>
#       <td id="T_19dd9_row0_col9" class="data row0 col9" >2.9490</td>
#     </tr>
#     <tr>
#       <th id="T_19dd9_level0_row1" class="row_heading level0 row1" >lightgbm</th>
#       <td id="T_19dd9_row1_col0" class="data row1 col0" >Light Gradient Boosting Machine</td>
#       <td id="T_19dd9_row1_col1" class="data row1 col1" >0.9786</td>
#       <td id="T_19dd9_row1_col2" class="data row1 col2" >0.9791</td>
#       <td id="T_19dd9_row1_col3" class="data row1 col3" >0.8379</td>
#       <td id="T_19dd9_row1_col4" class="data row1 col4" >0.9763</td>
#       <td id="T_19dd9_row1_col5" class="data row1 col5" >0.8989</td>
#       <td id="T_19dd9_row1_col6" class="data row1 col6" >0.8871</td>
#       <td id="T_19dd9_row1_col7" class="data row1 col7" >0.8920</td>
#       <td id="T_19dd9_row1_col8" class="data row1 col8" >0.9446</td>
#       <td id="T_19dd9_row1_col9" class="data row1 col9" >4.0650</td>
#     </tr>
#     <tr>
#       <th id="T_19dd9_level0_row2" class="row_heading level0 row2" >rf</th>
#       <td id="T_19dd9_row2_col0" class="data row2 col0" >Random Forest Classifier</td>
#       <td id="T_19dd9_row2_col1" class="data row2 col1" >0.9786</td>
#       <td id="T_19dd9_row2_col2" class="data row2 col2" >0.9795</td>
#       <td id="T_19dd9_row2_col3" class="data row2 col3" >0.8377</td>
#       <td id="T_19dd9_row2_col4" class="data row2 col4" >0.9776</td>
#       <td id="T_19dd9_row2_col5" class="data row2 col5" >0.8987</td>
#       <td id="T_19dd9_row2_col6" class="data row2 col6" >0.8869</td>
#       <td id="T_19dd9_row2_col7" class="data row2 col7" >0.8923</td>
#       <td id="T_19dd9_row2_col8" class="data row2 col8" >0.9441</td>
#       <td id="T_19dd9_row2_col9" class="data row2 col9" >1.5290</td>
#     </tr>
#     <tr>
#       <th id="T_19dd9_level0_row3" class="row_heading level0 row3" >et</th>
#       <td id="T_19dd9_row3_col0" class="data row3 col0" >Extra Trees Classifier</td>
#       <td id="T_19dd9_row3_col1" class="data row3 col1" >0.9786</td>
#       <td id="T_19dd9_row3_col2" class="data row3 col2" >0.9759</td>
#       <td id="T_19dd9_row3_col3" class="data row3 col3" >0.8379</td>
#       <td id="T_19dd9_row3_col4" class="data row3 col4" >0.9760</td>
#       <td id="T_19dd9_row3_col5" class="data row3 col5" >0.8989</td>
#       <td id="T_19dd9_row3_col6" class="data row3 col6" >0.8871</td>
#       <td id="T_19dd9_row3_col7" class="data row3 col7" >0.8920</td>
#       <td id="T_19dd9_row3_col8" class="data row3 col8" >0.9437</td>
#       <td id="T_19dd9_row3_col9" class="data row3 col9" >1.4200</td>
#     </tr>
#     <tr>
#       <th id="T_19dd9_level0_row4" class="row_heading level0 row4" >lr</th>
#       <td id="T_19dd9_row4_col0" class="data row4 col0" >Logistic Regression</td>
#       <td id="T_19dd9_row4_col1" class="data row4 col1" >0.9765</td>
#       <td id="T_19dd9_row4_col2" class="data row4 col2" >0.9761</td>
#       <td id="T_19dd9_row4_col3" class="data row4 col3" >0.8510</td>
#       <td id="T_19dd9_row4_col4" class="data row4 col4" >0.9482</td>
#       <td id="T_19dd9_row4_col5" class="data row4 col5" >0.8925</td>
#       <td id="T_19dd9_row4_col6" class="data row4 col6" >0.8795</td>
#       <td id="T_19dd9_row4_col7" class="data row4 col7" >0.8837</td>
#       <td id="T_19dd9_row4_col8" class="data row4 col8" >0.9413</td>
#       <td id="T_19dd9_row4_col9

# %% [markdown]
# # Removing multicollinearity

# %%
clf1 = setup(data = df_train, 
             target = 'target', 
             numeric_features=numeric_feature_list,
             silent=True,
             log_experiment = True,
             use_gpu=True,
             experiment_name = 'removing multicollinearity',
             remove_multicollinearity = True, multicollinearity_threshold = 0.6,
            )
add_metric('apc', 'APC', average_precision_score, target = 'pred_proba')
best = compare_models(sort="APC")
# Out:
# <style type="text/css">
# #T_35517 th {
#   text-align: left;
# }
# #T_35517_row0_col0, #T_35517_row0_col2, #T_35517_row0_col3, #T_35517_row0_col4, #T_35517_row1_col0, #T_35517_row1_col1, #T_35517_row1_col2, #T_35517_row1_col3, #T_35517_row1_col5, #T_35517_row1_col6, #T_35517_row1_col7, #T_35517_row1_col8, #T_35517_row2_col0, #T_35517_row2_col1, #T_35517_row2_col2, #T_35517_row2_col3, #T_35517_row2_col4, #T_35517_row2_col5, #T_35517_row2_col6, #T_35517_row2_col7, #T_35517_row2_col8, #T_35517_row3_col0, #T_35517_row3_col1, #T_35517_row3_col2, #T_35517_row3_col3, #T_35517_row3_col4, #T_35517_row3_col5, #T_35517_row3_col6, #T_35517_row3_col7, #T_35517_row3_col8, #T_35517_row4_col0, #T_35517_row4_col1, #T_35517_row4_col3, #T_35517_row4_col4, #T_35517_row4_col5, #T_35517_row4_col6, #T_35517_row4_col7, #T_35517_row4_col8, #T_35517_row5_col0, #T_35517_row5_col1, #T_35517_row5_col2, #T_35517_row5_col4, #T_35517_row5_col5, #T_35517_row5_col6, #T_35517_row5_col7, #T_35517_row5_col8, #T_35517_row6_col0, #T_35517_row6_col1, #T_35517_row6_col2, #T_35517_row6_col3, #T_35517_row6_col4, #T_35517_row6_col5, #T_35517_row6_col6, #T_35517_row6_col7, #T_35517_row6_col8, #T_35517_row7_col0, #T_35517_row7_col1, #T_35517_row7_col2, #T_35517_row7_col3, #T_35517_row7_col4, #T_35517_row7_col5, #T_35517_row7_col6, #T_35517_row7_col7, #T_35517_row7_col8, #T_35517_row8_col0, #T_35517_row8_col1, #T_35517_row8_col2, #T_35517_row8_col3, #T_35517_row8_col4, #T_35517_row8_col5, #T_35517_row8_col6, #T_35517_row8_col7, #T_35517_row8_col8, #T_35517_row9_col0, #T_35517_row9_col1, #T_35517_row9_col2, #T_35517_row9_col3, #T_35517_row9_col4, #T_35517_row9_col5, #T_35517_row9_col6, #T_35517_row9_col7, #T_35517_row9_col8, #T_35517_row10_col0, #T_35517_row10_col1, #T_35517_row10_col2, #T_35517_row10_col3, #T_35517_row10_col4, #T_35517_row10_col5, #T_35517_row10_col6, #T_35517_row10_col7, #T_35517_row10_col8, #T_35517_row11_col0, #T_35517_row11_col1, #T_35517_row11_col2, #T_35517_row11_col3, #T_35517_row11_col4, #T_35517_row11_col5, #T_35517_row11_col6, #T_35517_row11_col7, #T_35517_row11_col8, #T_35517_row12_col0, #T_35517_row12_col1, #T_35517_row12_col2, #T_35517_row12_col3, #T_35517_row12_col4, #T_35517_row12_col5, #T_35517_row12_col6, #T_35517_row12_col7, #T_35517_row12_col8, #T_35517_row13_col0, #T_35517_row13_col1, #T_35517_row13_col2, #T_35517_row13_col3, #T_35517_row13_col4, #T_35517_row13_col5, #T_35517_row13_col6, #T_35517_row13_col7, #T_35517_row13_col8 {
#   text-align: left;
# }
# #T_35517_row0_col1, #T_35517_row0_col5, #T_35517_row0_col6, #T_35517_row0_col7, #T_35517_row0_col8, #T_35517_row1_col4, #T_35517_row4_col2, #T_35517_row5_col3 {
#   text-align: left;
#   background-color: yellow;
# }
# #T_35517_row0_col9, #T_35517_row1_col9, #T_35517_row2_col9, #T_35517_row3_col9, #T_35517_row4_col9, #T_35517_row5_col9, #T_35517_row6_col9, #T_35517_row7_col9, #T_35517_row8_col9, #T_35517_row9_col9, #T_35517_row10_col9, #T_35517_row12_col9, #T_35517_row13_col9 {
#   text-align: left;
#   background-color: lightgrey;
# }
# #T_35517_row11_col9 {
#   text-align: left;
#   background-color: yellow;
#   background-color: lightgrey;
# }
# </style>
# <table id="T_35517">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_35517_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_35517_level0_col1" class="col_heading level0 col1" >Accuracy</th>
#       <th id="T_35517_level0_col2" class="col_heading level0 col2" >AUC</th>
#       <th id="T_35517_level0_col3" class="col_heading level0 col3" >Recall</th>
#       <th id="T_35517_level0_col4" class="col_heading level0 col4" >Prec.</th>
#       <th id="T_35517_level0_col5" class="col_heading level0 col5" >F1</th>
#       <th id="T_35517_level0_col6" class="col_heading level0 col6" >Kappa</th>
#       <th id="T_35517_level0_col7" class="col_heading level0 col7" >MCC</th>
#       <th id="T_35517_level0_col8" class="col_heading level0 col8" >APC</th>
#       <th id="T_35517_level0_col9" class="col_heading level0 col9" >TT (Sec)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_35517_level0_row0" class="row_heading level0 row0" >lightgbm</th>
#       <td id="T_35517_row0_col0" class="data row0 col0" >Light Gradient Boosting Machine</td>
#       <td id="T_35517_row0_col1" class="data row0 col1" >0.9765</td>
#       <td id="T_35517_row0_col2" class="data row0 col2" >0.9751</td>
#       <td id="T_35517_row0_col3" class="data row0 col3" >0.8229</td>
#       <td id="T_35517_row0_col4" class="data row0 col4" >0.9683</td>
#       <td id="T_35517_row0_col5" class="data row0 col5" >0.8885</td>
#       <td id="T_35517_row0_col6" class="data row0 col6" >0.8755</td>
#       <td id="T_35517_row0_col7" class="data row0 col7" >0.8798</td>
#       <td id="T_35517_row0_col8" class="data row0 col8" >0.9324</td>
#       <td id="T_35517_row0_col9" class="data row0 col9" >2.4160</td>
#     </tr>
#     <tr>
#       <th id="T_35517_level0_row1" class="row_heading level0 row1" >et</th>
#       <td id="T_35517_row1_col0" class="data row1 col0" >Extra Trees Classifier</td>
#       <td id="T_35517_row1_col1" class="data row1 col1" >0.9755</td>
#       <td id="T_35517_row1_col2" class="data row1 col2" >0.9739</td>
#       <td id="T_35517_row1_col3" class="data row1 col3" >0.8004</td>
#       <td id="T_35517_row1_col4" class="data row1 col4" >0.9847</td>
#       <td id="T_35517_row1_col5" class="data row1 col5" >0.8815</td>
#       <td id="T_35517_row1_col6" class="data row1 col6" >0.8681</td>
#       <td id="T_35517_row1_col7" class="data row1 col7" >0.8747</td>
#       <td id="T_35517_row1_col8" class="data row1 col8" >0.9294</td>
#       <td id="T_35517_row1_col9" class="data row1 col9" >0.8600</td>
#     </tr>
#     <tr>
#       <th id="T_35517_level0_row2" class="row_heading level0 row2" >rf</th>
#       <td id="T_35517_row2_col0" class="data row2 col0" >Random Forest Classifier</td>
#       <td id="T_35517_row2_col1" class="data row2 col1" >0.9760</td>
#       <td id="T_35517_row2_col2" class="data row2 col2" >0.9722</td>
#       <td id="T_35517_row2_col3" class="data row2 col3" >0.8184</td>
#       <td id="T_35517_row2_col4" class="data row2 col4" >0.9687</td>
#       <td id="T_35517_row2_col5" class="data row2 col5" >0.8856</td>
#       <td id="T_35517_row2_col6" class="data row2 col6" >0.8724</td>
#       <td id="T_35517_row2_col7" class="data row2 col7" >0.8772</td>
#       <td id="T_35517_row2_col8" class="data row2 col8" >0.9280</td>
#       <td id="T_35517_row2_col9" class="data row2 col9" >1.0430</td>
#     </tr>
#     <tr>
#       <th id="T_35517_level0_row3" class="row_heading level0 row3" >lda</th>
#       <td id="T_35517_row3_col0" class="data row3 col0" >Linear Discriminant Analysis</td>
#       <td id="T_35517_row3_col1" class="data row3 col1" >0.9699</td>
#       <td id="T_35517_row3_col2" class="data row3 col2" >0.9522</td>
#       <td id="T_35517_row3_col3" class="data row3 col3" >0.7516</td>
#       <td id="T_35517_row3_col4" class="data row3 col4" >0.9842</td>
#       <td id="T_35517_row3_col5" class="data row3 col5" >0.8503</td>
#       <td id="T_35517_row3_col6" class="data row3 col6" >0.8340</td>
#       <td id="T_35517_row3_col7" class="data row3 col7" >0.8445</td>
#       <td id="T_35517_row3_col8" class="data row3 col8" >0.9112</td>
#       <td id="T_35517_row3_col9" class="data row3 col9" >0.0470</td>
#     </tr>
#     <tr>
#       <th id="T_35517_level0_row4" class="row_heading level0 row4" >gbc</th>
#       <td id="T_35517_row4_col0" class="data row4 col0" >Gradient Boosting Classifier</td>
#       <td id="T_35517_row4_col1" class="data row4 col1" >0.9724</td>
#       <td id="T_35517_row4_col2" class="data row4 col2" >0.9771</td>
#       <td id="T_35517_row4_col3" class="data row4 col3" >0.8184</td>
#       <td id="T_35517_row4_col4" class="data row4 col4" >0.9343</td>
#       <td id="T_35517_row4_col5" class="data row4 col5" >0.8707</td>
#       <td id="T_35517_row4_col6" class="data row4 col6" >0.8555</td>
#       <td id="T_35517_row4_col7" class="data row4 col7" >0.8589</td>
#       <td id="T_35517_row4_col8" class="data row4 col8" >0.9072</td>
#       <td id="T_35517

# %% [markdown]
# # PCA

# %%
clf1 = setup(data = df_train, 
             target = 'target', 
             numeric_features=numeric_feature_list,
             silent=True,
             log_experiment = True,
             use_gpu=True,
             experiment_name = 'pca',
             pca = True, pca_components = 10
            )
add_metric('apc', 'APC', average_precision_score, target = 'pred_proba')
best = compare_models(sort="APC")
# Out:
# <style type="text/css">
# #T_725e0 th {
#   text-align: left;
# }
# #T_725e0_row0_col0, #T_725e0_row0_col1, #T_725e0_row0_col3, #T_725e0_row0_col4, #T_725e0_row0_col5, #T_725e0_row0_col6, #T_725e0_row0_col7, #T_725e0_row1_col0, #T_725e0_row1_col1, #T_725e0_row1_col2, #T_725e0_row1_col3, #T_725e0_row1_col4, #T_725e0_row1_col5, #T_725e0_row1_col6, #T_725e0_row1_col7, #T_725e0_row1_col8, #T_725e0_row2_col0, #T_725e0_row2_col1, #T_725e0_row2_col2, #T_725e0_row2_col3, #T_725e0_row2_col4, #T_725e0_row2_col5, #T_725e0_row2_col6, #T_725e0_row2_col7, #T_725e0_row2_col8, #T_725e0_row3_col0, #T_725e0_row3_col2, #T_725e0_row3_col4, #T_725e0_row3_col8, #T_725e0_row4_col0, #T_725e0_row4_col1, #T_725e0_row4_col2, #T_725e0_row4_col3, #T_725e0_row4_col4, #T_725e0_row4_col5, #T_725e0_row4_col6, #T_725e0_row4_col7, #T_725e0_row4_col8, #T_725e0_row5_col0, #T_725e0_row5_col1, #T_725e0_row5_col2, #T_725e0_row5_col3, #T_725e0_row5_col4, #T_725e0_row5_col5, #T_725e0_row5_col6, #T_725e0_row5_col7, #T_725e0_row5_col8, #T_725e0_row6_col0, #T_725e0_row6_col1, #T_725e0_row6_col2, #T_725e0_row6_col3, #T_725e0_row6_col4, #T_725e0_row6_col5, #T_725e0_row6_col6, #T_725e0_row6_col7, #T_725e0_row6_col8, #T_725e0_row7_col0, #T_725e0_row7_col1, #T_725e0_row7_col2, #T_725e0_row7_col3, #T_725e0_row7_col4, #T_725e0_row7_col5, #T_725e0_row7_col6, #T_725e0_row7_col7, #T_725e0_row7_col8, #T_725e0_row8_col0, #T_725e0_row8_col1, #T_725e0_row8_col2, #T_725e0_row8_col3, #T_725e0_row8_col4, #T_725e0_row8_col5, #T_725e0_row8_col6, #T_725e0_row8_col7, #T_725e0_row8_col8, #T_725e0_row9_col0, #T_725e0_row9_col1, #T_725e0_row9_col2, #T_725e0_row9_col3, #T_725e0_row9_col4, #T_725e0_row9_col5, #T_725e0_row9_col6, #T_725e0_row9_col7, #T_725e0_row9_col8, #T_725e0_row10_col0, #T_725e0_row10_col1, #T_725e0_row10_col2, #T_725e0_row10_col3, #T_725e0_row10_col4, #T_725e0_row10_col5, #T_725e0_row10_col6, #T_725e0_row10_col7, #T_725e0_row10_col8, #T_725e0_row11_col0, #T_725e0_row11_col1, #T_725e0_row11_col2, #T_725e0_row11_col3, #T_725e0_row11_col4, #T_725e0_row11_col5, #T_725e0_row11_col6, #T_725e0_row11_col7, #T_725e0_row11_col8, #T_725e0_row12_col0, #T_725e0_row12_col1, #T_725e0_row12_col2, #T_725e0_row12_col3, #T_725e0_row12_col4, #T_725e0_row12_col5, #T_725e0_row12_col6, #T_725e0_row12_col7, #T_725e0_row12_col8, #T_725e0_row13_col0, #T_725e0_row13_col1, #T_725e0_row13_col2, #T_725e0_row13_col3, #T_725e0_row13_col5, #T_725e0_row13_col6, #T_725e0_row13_col7, #T_725e0_row13_col8 {
#   text-align: left;
# }
# #T_725e0_row0_col2, #T_725e0_row0_col8, #T_725e0_row3_col1, #T_725e0_row3_col3, #T_725e0_row3_col5, #T_725e0_row3_col6, #T_725e0_row3_col7, #T_725e0_row13_col4 {
#   text-align: left;
#   background-color: yellow;
# }
# #T_725e0_row0_col9, #T_725e0_row1_col9, #T_725e0_row2_col9, #T_725e0_row3_col9, #T_725e0_row4_col9, #T_725e0_row5_col9, #T_725e0_row6_col9, #T_725e0_row7_col9, #T_725e0_row8_col9, #T_725e0_row9_col9, #T_725e0_row10_col9, #T_725e0_row11_col9, #T_725e0_row12_col9 {
#   text-align: left;
#   background-color: lightgrey;
# }
# #T_725e0_row13_col9 {
#   text-align: left;
#   background-color: yellow;
#   background-color: lightgrey;
# }
# </style>
# <table id="T_725e0">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_725e0_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_725e0_level0_col1" class="col_heading level0 col1" >Accuracy</th>
#       <th id="T_725e0_level0_col2" class="col_heading level0 col2" >AUC</th>
#       <th id="T_725e0_level0_col3" class="col_heading level0 col3" >Recall</th>
#       <th id="T_725e0_level0_col4" class="col_heading level0 col4" >Prec.</th>
#       <th id="T_725e0_level0_col5" class="col_heading level0 col5" >F1</th>
#       <th id="T_725e0_level0_col6" class="col_heading level0 col6" >Kappa</th>
#       <th id="T_725e0_level0_col7" class="col_heading level0 col7" >MCC</th>
#       <th id="T_725e0_level0_col8" class="col_heading level0 col8" >APC</th>
#       <th id="T_725e0_level0_col9" class="col_heading level0 col9" >TT (Sec)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_725e0_level0_row0" class="row_heading level0 row0" >lr</th>
#       <td id="T_725e0_row0_col0" class="data row0 col0" >Logistic Regression</td>
#       <td id="T_725e0_row0_col1" class="data row0 col1" >0.9770</td>
#       <td id="T_725e0_row0_col2" class="data row0 col2" >0.9832</td>
#       <td id="T_725e0_row0_col3" class="data row0 col3" >0.8659</td>
#       <td id="T_725e0_row0_col4" class="data row0 col4" >0.9364</td>
#       <td id="T_725e0_row0_col5" class="data row0 col5" >0.8983</td>
#       <td id="T_725e0_row0_col6" class="data row0 col6" >0.8854</td>
#       <td id="T_725e0_row0_col7" class="data row0 col7" >0.8872</td>
#       <td id="T_725e0_row0_col8" class="data row0 col8" >0.9527</td>
#       <td id="T_725e0_row0_col9" class="data row0 col9" >0.1700</td>
#     </tr>
#     <tr>
#       <th id="T_725e0_level0_row1" class="row_heading level0 row1" >lightgbm</th>
#       <td id="T_725e0_row1_col0" class="data row1 col0" >Light Gradient Boosting Machine</td>
#       <td id="T_725e0_row1_col1" class="data row1 col1" >0.9775</td>
#       <td id="T_725e0_row1_col2" class="data row1 col2" >0.9820</td>
#       <td id="T_725e0_row1_col3" class="data row1 col3" >0.8574</td>
#       <td id="T_725e0_row1_col4" class="data row1 col4" >0.9500</td>
#       <td id="T_725e0_row1_col5" class="data row1 col5" >0.8999</td>
#       <td id="T_725e0_row1_col6" class="data row1 col6" >0.8874</td>
#       <td id="T_725e0_row1_col7" class="data row1 col7" >0.8897</td>
#       <td id="T_725e0_row1_col8" class="data row1 col8" >0.9524</td>
#       <td id="T_725e0_row1_col9" class="data row1 col9" >2.7280</td>
#     </tr>
#     <tr>
#       <th id="T_725e0_level0_row2" class="row_heading level0 row2" >rf</th>
#       <td id="T_725e0_row2_col0" class="data row2 col0" >Random Forest Classifier</td>
#       <td id="T_725e0_row2_col1" class="data row2 col1" >0.9796</td>
#       <td id="T_725e0_row2_col2" class="data row2 col2" >0.9815</td>
#       <td id="T_725e0_row2_col3" class="data row2 col3" >0.8703</td>
#       <td id="T_725e0_row2_col4" class="data row2 col4" >0.9551</td>
#       <td id="T_725e0_row2_col5" class="data row2 col5" >0.9093</td>
#       <td id="T_725e0_row2_col6" class="data row2 col6" >0.8979</td>
#       <td id="T_725e0_row2_col7" class="data row2 col7" >0.9000</td>
#       <td id="T_725e0_row2_col8" class="data row2 col8" >0.9501</td>
#       <td id="T_725e0_row2_col9" class="data row2 col9" >1.0740</td>
#     </tr>
#     <tr>
#       <th id="T_725e0_level0_row3" class="row_heading level0 row3" >et</th>
#       <td id="T_725e0_row3_col0" class="data row3 col0" >Extra Trees Classifier</td>
#       <td id="T_725e0_row3_col1" class="data row3 col1" >0.9821</td>
#       <td id="T_725e0_row3_col2" class="data row3 col2" >0.9802</td>
#       <td id="T_725e0_row3_col3" class="data row3 col3" >0.8833</td>
#       <td id="T_725e0_row3_col4" class="data row3 col4" >0.9634</td>
#       <td id="T_725e0_row3_col5" class="data row3 col5" >0.9209</td>
#       <td id="T_725e0_row3_col6" class="data row3 col6" >0.9108</td>
#       <td id="T_725e0_row3_col7" class="data row3 col7" >0.9124</td>
#       <td id="T_725e0_row3_col8" class="data row3 col8" >0.9498</td>
#       <td id="T_725e0_row3_col9" class="data row3 col9" >1.2280</td>
#     </tr>
#     <tr>
#       <th id="T_725e0_level0_row4" class="row_heading level0 row4" >gbc</th>
#       <td id="T_725e0_row4_col0" class="data row4 col0" >Gradient Boosting Classifier</td>
#       <td id="T_725e0_row4_col1" class="data row4 col1" >0.9765</td>
#       <td id="T_725e0_row4_col2" class="data row4 col2" >0.9809</td>
#       <td id="T_725e0_row4_col3" class="data row4 col3" >0.8529</td>
#       <td id="T_725e0_row4_col4" class="data row4 col4" >0.9450</td>
#       <td id="T_725e0_row4_col5" class="data row4 col5" >0.8953</td>
#       <td id="T_725e0_row4_col6" class="data row4 col6" >0.8821</td>
#       <td id="T_725e0_row4_col7" class="data row4 col7" >0.8844</td>
#       <td id="T_725e0_row4_col8" class="data row4 col8" >0.9465</td>
#       <td id="T_725e0_row4_col9

# %% [markdown]
# # Selected model

# %% [markdown]
# ### Keeping only performance increasing data preprocessing techniques

# %%
clf1 = setup(data = df_train, 
             target = 'target',
             numeric_features=numeric_feature_list,
             silent=True,
             log_experiment = True,
             use_gpu=True,
             experiment_name = 'selected_model',
             feature_interaction = True, feature_ratio = True, 
             fix_imbalance = True
            )
add_metric('apc', 'APC', average_precision_score, target = 'pred_proba')
best = compare_models(sort="APC")
# Out:
# <style type="text/css">
# #T_f33ca th {
#   text-align: left;
# }
# #T_f33ca_row0_col0, #T_f33ca_row0_col1, #T_f33ca_row0_col3, #T_f33ca_row0_col4, #T_f33ca_row0_col5, #T_f33ca_row0_col6, #T_f33ca_row0_col7, #T_f33ca_row1_col0, #T_f33ca_row1_col1, #T_f33ca_row1_col3, #T_f33ca_row1_col4, #T_f33ca_row1_col5, #T_f33ca_row1_col6, #T_f33ca_row1_col7, #T_f33ca_row1_col8, #T_f33ca_row2_col0, #T_f33ca_row2_col2, #T_f33ca_row2_col3, #T_f33ca_row2_col8, #T_f33ca_row3_col0, #T_f33ca_row3_col1, #T_f33ca_row3_col2, #T_f33ca_row3_col3, #T_f33ca_row3_col4, #T_f33ca_row3_col5, #T_f33ca_row3_col6, #T_f33ca_row3_col7, #T_f33ca_row3_col8, #T_f33ca_row4_col0, #T_f33ca_row4_col1, #T_f33ca_row4_col2, #T_f33ca_row4_col3, #T_f33ca_row4_col4, #T_f33ca_row4_col5, #T_f33ca_row4_col6, #T_f33ca_row4_col7, #T_f33ca_row4_col8, #T_f33ca_row5_col0, #T_f33ca_row5_col1, #T_f33ca_row5_col2, #T_f33ca_row5_col3, #T_f33ca_row5_col4, #T_f33ca_row5_col5, #T_f33ca_row5_col6, #T_f33ca_row5_col7, #T_f33ca_row5_col8, #T_f33ca_row6_col0, #T_f33ca_row6_col1, #T_f33ca_row6_col2, #T_f33ca_row6_col3, #T_f33ca_row6_col4, #T_f33ca_row6_col5, #T_f33ca_row6_col6, #T_f33ca_row6_col7, #T_f33ca_row6_col8, #T_f33ca_row7_col0, #T_f33ca_row7_col1, #T_f33ca_row7_col2, #T_f33ca_row7_col3, #T_f33ca_row7_col4, #T_f33ca_row7_col5, #T_f33ca_row7_col6, #T_f33ca_row7_col7, #T_f33ca_row7_col8, #T_f33ca_row8_col0, #T_f33ca_row8_col1, #T_f33ca_row8_col2, #T_f33ca_row8_col3, #T_f33ca_row8_col4, #T_f33ca_row8_col5, #T_f33ca_row8_col6, #T_f33ca_row8_col7, #T_f33ca_row8_col8, #T_f33ca_row9_col0, #T_f33ca_row9_col1, #T_f33ca_row9_col2, #T_f33ca_row9_col3, #T_f33ca_row9_col4, #T_f33ca_row9_col5, #T_f33ca_row9_col6, #T_f33ca_row9_col7, #T_f33ca_row9_col8, #T_f33ca_row10_col0, #T_f33ca_row10_col1, #T_f33ca_row10_col2, #T_f33ca_row10_col3, #T_f33ca_row10_col4, #T_f33ca_row10_col5, #T_f33ca_row10_col6, #T_f33ca_row10_col7, #T_f33ca_row10_col8, #T_f33ca_row11_col0, #T_f33ca_row11_col1, #T_f33ca_row11_col2, #T_f33ca_row11_col3, #T_f33ca_row11_col4, #T_f33ca_row11_col5, #T_f33ca_row11_col6, #T_f33ca_row11_col7, #T_f33ca_row11_col8, #T_f33ca_row12_col0, #T_f33ca_row12_col1, #T_f33ca_row12_col2, #T_f33ca_row12_col4, #T_f33ca_row12_col5, #T_f33ca_row12_col6, #T_f33ca_row12_col7, #T_f33ca_row12_col8, #T_f33ca_row13_col0, #T_f33ca_row13_col1, #T_f33ca_row13_col2, #T_f33ca_row13_col3, #T_f33ca_row13_col4, #T_f33ca_row13_col5, #T_f33ca_row13_col6, #T_f33ca_row13_col7, #T_f33ca_row13_col8 {
#   text-align: left;
# }
# #T_f33ca_row0_col2, #T_f33ca_row0_col8, #T_f33ca_row1_col2, #T_f33ca_row2_col1, #T_f33ca_row2_col4, #T_f33ca_row2_col5, #T_f33ca_row2_col6, #T_f33ca_row2_col7, #T_f33ca_row12_col3 {
#   text-align: left;
#   background-color: yellow;
# }
# #T_f33ca_row0_col9, #T_f33ca_row1_col9, #T_f33ca_row2_col9, #T_f33ca_row3_col9, #T_f33ca_row4_col9, #T_f33ca_row5_col9, #T_f33ca_row6_col9, #T_f33ca_row7_col9, #T_f33ca_row8_col9, #T_f33ca_row9_col9, #T_f33ca_row10_col9, #T_f33ca_row12_col9, #T_f33ca_row13_col9 {
#   text-align: left;
#   background-color: lightgrey;
# }
# #T_f33ca_row11_col9 {
#   text-align: left;
#   background-color: yellow;
#   background-color: lightgrey;
# }
# </style>
# <table id="T_f33ca">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_f33ca_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_f33ca_level0_col1" class="col_heading level0 col1" >Accuracy</th>
#       <th id="T_f33ca_level0_col2" class="col_heading level0 col2" >AUC</th>
#       <th id="T_f33ca_level0_col3" class="col_heading level0 col3" >Recall</th>
#       <th id="T_f33ca_level0_col4" class="col_heading level0 col4" >Prec.</th>
#       <th id="T_f33ca_level0_col5" class="col_heading level0 col5" >F1</th>
#       <th id="T_f33ca_level0_col6" class="col_heading level0 col6" >Kappa</th>
#       <th id="T_f33ca_level0_col7" class="col_heading level0 col7" >MCC</th>
#       <th id="T_f33ca_level0_col8" class="col_heading level0 col8" >APC</th>
#       <th id="T_f33ca_level0_col9" class="col_heading level0 col9" >TT (Sec)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_f33ca_level0_row0" class="row_heading level0 row0" >rf</th>
#       <td id="T_f33ca_row0_col0" class="data row0 col0" >Random Forest Classifier</td>
#       <td id="T_f33ca_row0_col1" class="data row0 col1" >0.9775</td>
#       <td id="T_f33ca_row0_col2" class="data row0 col2" >0.9842</td>
#       <td id="T_f33ca_row0_col3" class="data row0 col3" >0.8676</td>
#       <td id="T_f33ca_row0_col4" class="data row0 col4" >0.9407</td>
#       <td id="T_f33ca_row0_col5" class="data row0 col5" >0.9017</td>
#       <td id="T_f33ca_row0_col6" class="data row0 col6" >0.8890</td>
#       <td id="T_f33ca_row0_col7" class="data row0 col7" >0.8906</td>
#       <td id="T_f33ca_row0_col8" class="data row0 col8" >0.9511</td>
#       <td id="T_f33ca_row0_col9" class="data row0 col9" >2.0110</td>
#     </tr>
#     <tr>
#       <th id="T_f33ca_level0_row1" class="row_heading level0 row1" >gbc</th>
#       <td id="T_f33ca_row1_col0" class="data row1 col0" >Gradient Boosting Classifier</td>
#       <td id="T_f33ca_row1_col1" class="data row1 col1" >0.9755</td>
#       <td id="T_f33ca_row1_col2" class="data row1 col2" >0.9842</td>
#       <td id="T_f33ca_row1_col3" class="data row1 col3" >0.8723</td>
#       <td id="T_f33ca_row1_col4" class="data row1 col4" >0.9212</td>
#       <td id="T_f33ca_row1_col5" class="data row1 col5" >0.8950</td>
#       <td id="T_f33ca_row1_col6" class="data row1 col6" >0.8812</td>
#       <td id="T_f33ca_row1_col7" class="data row1 col7" >0.8822</td>
#       <td id="T_f33ca_row1_col8" class="data row1 col8" >0.9505</td>
#       <td id="T_f33ca_row1_col9" class="data row1 col9" >12.0810</td>
#     </tr>
#     <tr>
#       <th id="T_f33ca_level0_row2" class="row_heading level0 row2" >lightgbm</th>
#       <td id="T_f33ca_row2_col0" class="data row2 col0" >Light Gradient Boosting Machine</td>
#       <td id="T_f33ca_row2_col1" class="data row2 col1" >0.9811</td>
#       <td id="T_f33ca_row2_col2" class="data row2 col2" >0.9830</td>
#       <td id="T_f33ca_row2_col3" class="data row2 col3" >0.8850</td>
#       <td id="T_f33ca_row2_col4" class="data row2 col4" >0.9555</td>
#       <td id="T_f33ca_row2_col5" class="data row2 col5" >0.9170</td>
#       <td id="T_f33ca_row2_col6" class="data row2 col6" >0.9064</td>
#       <td id="T_f33ca_row2_col7" class="data row2 col7" >0.9084</td>
#       <td id="T_f33ca_row2_col8" class="data row2 col8" >0.9500</td>
#       <td id="T_f33ca_row2_col9" class="data row2 col9" >1.8030</td>
#     </tr>
#     <tr>
#       <th id="T_f33ca_level0_row3" class="row_heading level0 row3" >ada</th>
#       <td id="T_f33ca_row3_col0" class="data row3 col0" >Ada Boost Classifier</td>
#       <td id="T_f33ca_row3_col1" class="data row3 col1" >0.9740</td>
#       <td id="T_f33ca_row3_col2" class="data row3 col2" >0.9781</td>
#       <td id="T_f33ca_row3_col3" class="data row3 col3" >0.8810</td>
#       <td id="T_f33ca_row3_col4" class="data row3 col4" >0.9025</td>
#       <td id="T_f33ca_row3_col5" class="data row3 col5" >0.8901</td>
#       <td id="T_f33ca_row3_col6" class="data row3 col6" >0.8753</td>
#       <td id="T_f33ca_row3_col7" class="data row3 col7" >0.8764</td>
#       <td id="T_f33ca_row3_col8" class="data row3 col8" >0.9459</td>
#       <td id="T_f33ca_row3_col9" class="data row3 col9" >4.9330</td>
#     </tr>
#     <tr>
#       <th id="T_f33ca_level0_row4" class="row_heading level0 row4" >et</th>
#       <td id="T_f33ca_row4_col0" class="data row4 col0" >Extra Trees Classifier</td>
#       <td id="T_f33ca_row4_col1" class="data row4 col1" >0.9796</td>
#       <td id="T_f33ca_row4_col2" class="data row4 col2" >0.9784</td>
#       <td id="T_f33ca_row4_col3" class="data row4 col3" >0.8721</td>
#       <td id="T_f33ca_row4_col4" class="data row4 col4" >0.9551</td>
#       <td id="T_f33ca_row4_col5" class="data row4 col5" >0.9101</td>
#       <td id="T_f33ca_row4_col6" class="data row4 col6" >0.8987</td>
#       <td id="T_f33ca_row4_col7" class="data row4 col7" >0.9008</td>
#       <td id="T_f33ca_row4_col8" class="data row4 col8" >0.9454</td>
#       <td id="T_f33ca_row4_c

# %% [markdown]
# # Deploy the model

# %%
best
# Out:
# ExtraTreesClassifier(bootstrap=False, ccp_alpha=0.0, class_weight=None,
#                      criterion='gini', max_depth=None, max_features='auto',
#                      max_leaf_nodes=None, max_samples=None,
#                      min_impurity_decrease=0.0, min_impurity_split=None,
#                      min_samples_leaf=1, min_samples_split=2,
#                      min_weight_fraction_leaf=0.0, n_estimators=100, n_jobs=-1,
#                      oob_score=False, random_state=3225, verbose=0,
#                      warm_start=False)

# %%
# create api
create_api(best, 'fraud_voting_model_api')
# Out:
# API sucessfully created. This function only creates a POST API, it doesn't run it automatically.
#
# To run your API, please run this command --> !python fraud_voting_model_api.py

# %%
best
# Out:
# ExtraTreesClassifier(bootstrap=False, ccp_alpha=0.0, class_weight=None,
#                      criterion='gini', max_depth=None, max_features='auto',
#                      max_leaf_nodes=None, max_samples=None,
#                      min_impurity_decrease=0.0, min_impurity_split=None,
#                      min_samples_leaf=1, min_samples_split=2,
#                      min_weight_fraction_leaf=0.0, n_estimators=100, n_jobs=-1,
#                      oob_score=False, random_state=8777, verbose=0,
#                      warm_start=False)

# %% [markdown]
# # Test REST API

# %%
# inference data
df_test.loc[df_test.target == 1].iloc[0]
# Out:
# ERROR! Session/line number was not unique in database. History logging moved to new session 252
# Time          68207
# V1       -13.192671
# V2        12.785971
# V3         -9.90665
# V4         3.320337
# V5        -4.801176
# V6         5.760059
# V7       -18.750889
# V8       -37.353443
# V9         -0.39154
# V10       -5.052502
# V11        4.406806
# V12       -4.610756
# V13       -1.909488
# V14       -9.072711
# V15       -0.226074
# V16       -6.211557
# V17       -6.248145
# V18       -3.149247
# V19        0.051576
# V20        -3.49305
# V21       27.202839
# V22       -8.887017
# V23        5.303607
# V24       -0.639435
# V25        0.263203
# V26       -0.108877
# V27        1.269566
# V28        0.939407
# Amount          1.0
# target          1.0
# Name: 102441, dtype: object

# %% [markdown]
# # Test REST API - in another way

# %%
import requests

# %%
df_test.loc[df_test.target == 1].iloc[0].to_json(compression="dict")
# Out:
# '{"Time":68207,"V1":-13.1926709562,"V2":12.7859706383,"V3":-9.9066500209,"V4":3.3203368829,"V5":-4.8011759323,"V6":5.7600585562,"V7":-18.750889158,"V8":-37.3534426379,"V9":-0.3915397439,"V10":-5.0525023671,"V11":4.4068055236,"V12":-4.6107564774,"V13":-1.9094879697,"V14":-9.072710934,"V15":-0.2260744509,"V16":-6.2115574821,"V17":-6.2481453534,"V18":-3.1492466947,"V19":0.0515761185,"V20":-3.4930499152,"V21":27.2028391573,"V22":-8.8870171409,"V23":5.3036069038,"V24":-0.6394348023,"V25":0.2632031235,"V26":-0.10887693,"V27":1.2695663554,"V28":0.9394073628,"Amount":1.0,"target":1.0}'

# %%
import json
url = 'http://127.0.0.1:8001/get_predict/'

params = json.loads(df_test.loc[df_test.target == 1].iloc[0].to_json())
response = requests.get(url, params).json()
print(response)
# Out:
# {'prediction': ['1.0']}

# %%
# !python fraud_voting_model_api.py
# Out:
# /Users/gerzsonboros/miniconda3/lib/python3.8/site-packages/sklearn/utils/deprecation.py:143: FutureWarning: The sklearn.metrics.classification module is  deprecated in version 0.22 and will be removed in version 0.24. The corresponding classes / functions should instead be imported from sklearn.metrics. Anything that cannot be imported from sklearn.metrics is now part of the private API.
#   warnings.warn(message, FutureWarning)
# Transformation Pipeline and Model Successfully Loaded
# INFO:     Started server process [2345]
# INFO:     Waiting for application startup.
# INFO:     Application startup complete.
# INFO:     Uvicorn running on http://127.0.0.1:8000 (Press CTRL+C to quit)
# INFO:     127.0.0.1:56959 - "GET / HTTP/1.1" 404 Not Found
# INFO:     127.0.0.1:56959 - "GET /favicon.ico HTTP/1.1" 404 Not Found
# INFO:     127.0.0.1:56960 - "GET /docs HTTP/1.1" 200 OK
# INFO:     127.0.0.1:56960 - "GET /openapi.json HTTP/1.1" 200 OK
# ^C
# INFO:     Shutting down
# INFO:     Waiting for application shutdown.
# INFO:     Application shutdown complete.
# INFO:     Finished server process [2345]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# File ~/miniconda3/lib/python3.8/site-packages/IPython/utils/_process_posix.py:153, in ProcessHandler.system(self, cmd)
#     150 while True:
#     151     # res is the index of the pattern that caused the match, so we
#     152     # know whether we've finished (if we matched EOF) or not
# --> 153     res_idx = child.expect_list(patterns, self.read_timeout)
#     154     print(child.before[out_size:].decode(enc, 'replace'), end='')
#
# File ~/miniconda3/lib/python3.8/site-packages/pexpect/spawnbase.py:372, in SpawnBase.expect_list(self, pattern_list, timeout, searchwindowsize, async_, **kw)
#     371 else:
# --> 372     return exp.expect_loop(timeout)
#
# File ~/miniconda3/lib/python3.8/site-packages/pexpect/expect.py:169, in Expecter.expect_loop(self, timeout)
#     168 # Still have time left, so read more data
# --> 169 incoming = spawn.read_nonblocking(spawn.maxread, timeout)
#     170 if self.spawn.delayafterread is not None:
#
# File ~/miniconda3/lib/python3.8/site-packages/pexpect/pty_spawn.py:500, in spawn.read_nonblocking(self, size, timeout)
#     497 # Because of the select(0) check above, we know that no data
#     498 # is available right now. But if a non-zero timeout is given
#     499 # (possibly timeout=None), we call select() with a timeout.
# --> 500 if (timeout != 0) and select(timeout):
#     501     return super(spawn, self).read_nonblocking(size)
#
# File ~/miniconda3/lib/python3.8/site-packages/pexpect/pty_spawn.py:450, in spawn.read_nonblocking.<locals>.select(timeout)
#     449 def select(timeout):
# --> 450     return select_ignore_interrupts([self.child_fd], [], [], timeout)[0]
#
# File ~/miniconda3/lib/python3.8/site-packages/pexpect/utils.py:143, in select_ignore_interrupts(iwtd, owtd, ewtd, timeout)
#     142 try:
# --> 143     return select.select(iwtd, owtd, ewtd, timeout)
#     144 except InterruptedError:
#
# KeyboardInterrupt:
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[21], line 1
# ----> 1 get_ipython().system('python fraud_voting_model_api.py')
#
# File ~/miniconda3/lib/python3.8/site-packages/ipykernel/zmqshell.py:636, in ZMQInteractiveShell.system_piped(self, cmd)
#     634         self.user_ns["_exit_code"] = system(cmd)
#     635 else:
# --> 636     self.user_ns["_exit_code"] = system(self.var_expand(cmd, depth=1))
#
# File ~/miniconda3/lib/python3.8/site-packages/IPython/utils/_process_posix.py:177, in ProcessHandler.system(self, cmd)
#     174         pass
#     175     finally:
#     176         # Ensure the subprocess really is terminated
# --> 177         child.terminate(force=True)
#     178 # add isalive check, to ensure exitstatus is set:
#     179 child.isalive()
#
# File ~/miniconda3/lib/python3.8/site-packages/pexpect/pty_spawn.py:642, in spawn.terminate(self, force)
#     640 try:
#     641     self.kill(signal.SIGHUP)
# --> 642     time.sleep(self.delayafterterminate)
#     643     if not self.isalive():
#     644         return True
#
# KeyboardInterrupt:

# %% [markdown]
# # Create a docker

# %%
create_docker('fraud_voting_model_api_with_get_for_docker3')
# Out:
# Writing requirements.txt
# Writing Dockerfile
# Dockerfile and requirements.txt successfully created.
# To build image you have to run --> !docker image build -f "Dockerfile" -t IMAGE_NAME:IMAGE_TAG .

# %%
# !docker image build -f "Dockerfile_8007" -t fraud_voting_model_api_with_get_for_docker3:latest .
# Out:
# [+] Building 0.0s (0/1)
# [+] Building 0.1s (1/2)
#  => [internal] load build definition from Dockerfile                       0.1s
#  => => transferring dockerfile: 247B                                       0.1s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context:                                               0.0s
# [+] Building 0.3s (2/2)
#  => [internal] load build definition from Dockerfile                       0.1s
#  => => transferring dockerfile: 247B                                       0.1s
#  => [internal] load .dockerignore                                          0.1s
#  => => transferring context: 2B                                            0.0s
# [+] Building 0.4s (4/9)
#  => [internal] load build definition from Dockerfile                       0.1s
#  => => transferring dockerfile: 247B                                       0.1s
#  => [internal] load .dockerignore                                          0.1s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/library/python:3.8-slim         0.0s
#  => [1/5] FROM docker.io/library/python:3.8-slim                           0.0s
#  => [internal] load build context                                          0.1s
# [+] Building 0.6s (4/9)
#  => [internal] load build definition from Dockerfile                       0.1s
#  => => transferring dockerfile: 247B                                       0.1s
#  => [internal] load .dockerignore                                          0.1s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/library/python:3.8-slim         0.0s
#  => [1/5] FROM docker.io/library/python:3.8-slim                           0.0s
#  => [internal] load build context                                          0.3s
# [+] Building 0.7s (4/9)
#  => [internal] load build definition from Dockerfile                       0.1s
#  => => transferring dockerfile: 247B                                       0.1s
#  => [internal] load .dockerignore                                          0.1s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/library/python:3.8-slim         0.0s
#  => [1/5] FROM docker.io/library/python:3.8-slim                           0.0s
#  => [internal] load build context                                          0.4s
# [+] Building 0.9s (4/9)
#  => [internal] load build definition from Dockerfile                       0.1s
#  => => transferring dockerfile: 247B                                       0.1s
#  => [internal] load .dockerignore                                          0.1s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/library/python:3.8-slim         0.0s
#  => [1/5] FROM docker.io/library/python:3.8-slim                           0.0s
#  => [internal] load build context                                          0.6s
# [+] Building 1.0s (4/9)
#  => [internal] load build definition from Dockerfile                       0.1s
#  => => transferring dockerfile: 247B                                       0.1s
#  => [internal] load .dockerignore                                          0.1s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/library/python:3.8-slim         0.0s
#  => [1/5] FROM docker.io/library/python:3.8-slim                           0.0s
#  => [internal] load build context                                          0.7s
# [+] Building 1.2s (4/9)
#  => [internal] load build definition from Dockerfile                       0.1s
#  => => transferring dockerfile: 247B                                       0.1s
#  => [internal] load .dockerignore                                          0.1s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/library/python:3.8-slim         0.0s
#  => [1/5] FROM docker.io/library/python:3.8-slim                           0.0s
#  => [internal] load build context                                          0.9s
# [+] Building 1.3s (4/9)
#  => [internal] load build definition from Dockerfile                       0.1s
#  => => transferring dockerfile: 247B                                       0.1s
#  => [internal] load .dockerignore                                          0.1s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/library/python:3.8-slim         0.0s
#  => [1/5] FROM docker.io/library/python:3.8-slim                           0.0s
#  => [internal] load build context                                          1.0s
# [+] Building 1.5s (4/9)
#  => [internal] load build definition from Dockerfile                       0.1s
#  => => transferring dockerfile: 247B                                       0.1s
#  => [internal] load .dockerignore                                          0.1s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/library/python:3.8-slim         0.0s
#  => [1/5] FROM docker.io/library/python:3.8-slim                           0.0s
#  => [internal] load build context                                          1.2s
# [+] Building 1.6s (4/9)
#  => [internal] load build definition from Dockerfile                       0.1s
#  => => transferring dockerfile: 247B                                       0.1s
#  => [internal] load .dockerignore                                          0.1s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/library/python:3.8-slim         0.0s
#  => [1/5] FROM docker.io/library/python:3.8-slim                           0.0s
#  => [internal] load build context                                          1.3s
# [+] Building 1.8s (4/9)
#  => [internal] load build definition from Dockerfile                       0.1s
#  => => transferring dockerfile: 247B                                       0.1s
#  => [internal] load .dockerignore                                          0.1s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/library/python:3.8-slim         0.0s
#  => [1/5] FROM docker.io/library/python:3.8-slim                           0.0s
#  => [internal] load build context                                          1.5s
# [+] Building 1.9s (4/9)
#  => [internal] load build definition from Dockerfile                       0.1s
#  => => transferring dockerfile: 247B                                       0.1s
#  => [internal] load .dockerignore                                          0.1s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/library/python:3.8-slim         0.0s
#  => [1/5] FROM docker.io/library/python:3.8-slim                           0.0s
#  => [internal] load build context                                          1.6s
# [+] Building 2.1s (4/9)
#  => [internal] load build definition from Dockerfile                       0.1s
#  => => transferring dockerfile: 247B                                       0.1s
#  => [internal] load .dockerignore                                          0.1s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/library/python:3.8-slim         0.0s
#  => [1/5] FROM docker.io/library/python:3.8-slim                           0.0s
#  => [internal] load build context                                          1.8s
# [+] Building 2.2s (4/9)
#  => [internal] load build definition from Dockerfile                       0.1s
#  => => transferring dockerfile: 247B                                       0.1s
#  => [internal] load .dockerignore                                          0.1s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/library/python:3.8-slim         0.0s
#  => [1/5] FROM docker.io/library/python:3.8-slim                           0.0s
#  => [internal] load build context                                          1.9s
# [+] Building 2.3s (4/9)
#  => [internal] load build definition from Dockerfile                       0.1s
#  => => transferring dockerfile: 247B                                       0.1s
#  => [internal] load .dockerignore                                          0.1s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/library/python:3.8-slim         0.0s
#  => [1/5] FROM docker.io/library/python:3.8-slim                           0.0s
#  => [internal] load build context                                          2.1s
#  => => transferring context: 927.61kB                                      0.1s
# [+] Building 2.5s (4/9)
#  => [internal] load build definition from Dockerfile                       0.1s
#  => => transferring dockerfile: 247B                                       0.1s
#  => [internal] load .dockerignore                                          0.1s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/library/python:3.8-slim         0.0s
#  => [1/5] FROM docker.io/library/python:3.8-slim                           0.0s
#  => [internal] load build context                                          2.2s
#  => => transferring context: 1.43MB                                        0.3s
# [+] Building 2.6s (4/9)
#  => [internal] load build definition from Dockerfile                       0.1s
#  => => transferring dockerfile: 247B                                       0.1s
#  => [internal] load .dockerignore                                          0.1s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/library/python:3.8-slim         0.0s
#  => [1/5] FROM docker.io/library/python:3.8-slim                           0.0s
#  => [internal] load build context                                          2.4s
#  => => transferring context: 1.51MB                                        0.4s
# [+] Building 2.7s (4/9)
#  => [internal] load build definition from Dockerfile                       0.1s
#  => => transferring dockerfile: 247B                                       0.1s
#  => [internal] load .dockerignore                                          0.1s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/library/python:3.8-slim         0.0s
#  => [1/5] FROM docker.io/library/python:3.8-slim                           0.0s
#  => [internal] load build context                                          2.5s
#  => => transferring context: 5.30MB                                        0.5s
# [+] Building 2.8s (4/9)
#  => [internal] load build definition from Dockerfile                       0.1s
#  => => transferring dockerfile: 247B                                       0.1s
#  => [internal] load .dockerignore                                          0.1s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/library/python:3.8-slim         0.0s
#  => [1/5] FROM docker.io/library/python:3.8-slim                           0.0s
#  => [internal] load build context                                          2.6s
#  => => transferring context: 5.34MB                                        0.6s
# [+] Building 2.9s (4/9)
#  => [internal] load build definition from Dockerfile                       0.1s
#  => => transferring dockerfile: 247B                                       0.1s
#  => [internal] load .dockerignore                                          0.1s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/library/python:3.8-slim         0.0s
#  => [1/5] FROM docker.io/library/python:3.8-slim                           0.0s
#  => [internal] load build context                                          2.7s
#  => => transferring context: 6.49MB                                        0.7s
# [+] Building 3.0s (4/9)
#  => [internal] load build definition from Dockerfile                       0.1s
#  => => transferring dockerfile: 247B                                       0.1s
#  => [internal] load .dockerignore                                          0.1s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/library/python:3.8-slim         0.0s
#  => [1/5] FROM docker.io/library/python:3.8-slim                           0.0s
#  => [internal] load build context                                          2.8s
#  => => transferring context: 6.53MB                                        0.8s
# [+] Building 3.1s (4/9)
#  => [internal] load build definition from Dockerfile                       0.1s
#  => => transferring dockerfile: 247B                                       0.1s
#  => [internal] load .dockerignore                                          0.1s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/library/python:3.8-slim         0.0s
#  => [1/5] FROM docker.io/library/python:3.8-slim                           0.0s
#  => [internal] load build context                                          2.9s
#  => => transferring context: 6.63MB                                        0.9s
# [+] Building 3.3s (4/9)
#  => [internal] load build definition from Dockerfile                       0.1s
#  => => transferring dockerfile: 247B                                       0.1s
#  => [internal] load .dockerignore                                          0.1s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/library/python:3.8-slim         0.0s
#  => [1/5] FROM docker.io/library/python:3.8-slim                           0.0s
#  => [internal] load build context                                          3.0s
#  => => transferring context: 7.18MB                                        1.1s
# [+] Building 3.4s (4/9)
#  => [internal] load build definition from Dockerfile                       0.1s
#  => => transferring dockerfile: 247B                                       0.1s
#  => [internal] load .dockerignore                                          0.1s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/library/python:3.8-slim         0.0s
#  => [1/5] FROM docker.io/library/python:3.8-slim                           0.0s
#  => [internal] load build context                                          3.2s
#  => => transferring context: 7.43MB                                        1.2s
# [+] Building 3.5s (4/9)
#  => [internal] load build definition from Dockerfile                       0.1s
#  => => transferring dockerfile: 247B                                       0.1s
#  => [internal] load .dockerignore                                          0.1s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/library/python:3.8-slim         0.0s
#  => [1/5] FROM docker.io/library/python:3.8-slim                           0.0s
#  => [internal] load build context                                          3.3s
#  => => transferring context: 8.80MB                                        1.3s
# [+] Building 3.6s (4/9)
#  => [internal] load build definition from Dockerfile                       0.1s
#  => => transferring dockerfile: 247B                                       0.1s
#  => [internal] load .dockerignore                                          0.1s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/library/python:3.8-slim         0.0s
#  => [1/5] FROM docker.io/library/python:3.8-slim                           0.0s
#  => [internal] load build context                                          3.4s
#  => => transferring context: 10.66MB                                       1.4s
# [+] Building 3.8s (4/9)
#  => [internal] load build definition from Dockerfile                       0.1s
#  => => transferring dockerfile: 247B                                       0.1s
#  => [internal] load .dockerignore                                          0.1s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/library/python:3.8-slim         0.0s
#  => [1/5] FROM docker.io/library/python:3.8-slim                           0.0s
#  => [internal] load build context                                          3.5s
#  => => transferring context: 12.46MB                                       1.6s
# [+] Building 3.9s (4/9)
#  => [internal] load build definition from Dockerfile                       0.1s
#  => => transferring dockerfile: 247B                                       0.1s
#  => [internal] load .dockerignore                                          0.1s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/library/python:3.8-slim         0.0s
#  => [1/5] FROM docker.io/library/python:3.8-slim                           0.0s
#  => [internal] load build context                                          3.7s
#  => => transferring context: 17.82MB                                       1.7s
# [+] Building 4.1s (4/9)
#  => [internal] load build definition from Dockerfile                       0.1s
#  => => transferring dockerfile: 247B                                       0.1s
#  => [internal] load .dockerignore                                          0.1s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/library/python:3.8-slim         0.0s
#  => [1/5] FROM docker.io/library/python:3.8-slim                           0.0s
#  => [internal] load build context                                          3.8s
#  => => transferring context: 20.64MB                                       1.8s
# [+] Building 4.2s (4/9)
#  => [internal] load build definition from Dockerfile                       0.1s
#  => => transferring dockerfile: 247B                                       0.1s
#  => [internal] load .dockerignore                                          0.1s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/library/python:3.8-slim         0.0s
#  => [1/5] FROM docker.io/library/python:3.8-slim                           0.0s
#  => [internal] load build context                                          3.9s
#  => => transferring context: 23.07MB                                       2.0s
# [+] Building 4.3s (4/9)
#  => [internal] load build definition from Dockerfile                       0.1s
#  => => transferring dockerfile: 247B                                       0.1s
#  => [internal] load .dockerignore                                          0.1s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/library/python:3.8-slim         0.0s
#  => [1/5] FROM docker.io/library/python:3.8-slim                           0.0s
#  => [internal] load build context                                          4.0s
#  => => transferring context: 26.22MB                                       2.1s
# [+] Building 4.4s (4/9)
#  => [internal] load build definition from Dockerfile                       0.1s
#  => => transferring dockerfile: 247B                                       0.1s
#  => [internal] load .dockerignore                                          0.1s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/library/python:3.8-slim         0.0s
#  => [1/5] FROM docker.io/library/python:3.8-slim                           0.0s
#  => [internal] load build context                                          4.1s
#  => => transferring context: 30.25MB                                       2.2s
# [+] Building 4.5s (4/9)
#  => [internal] load build definition from Dockerfile                       0.1s
#  => => transferring dockerfile: 247B                                       0.1s
#  => [internal] load .dockerignore                                          0.1s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/library/python:3.8-slim         0.0s
#  => [1/5] FROM docker.io/library/python:3.8-slim                           0.0s
#  => [internal] load build context                                          4.2s
#  => => transferring context: 30.25MB                                       2.3s
# [+] Building 4.7s (4/9)
#  => [internal] load build definition from Dockerfile                       0.1s
#  => => transferring dockerfile: 247B                                       0.1s
#  => [internal] load .dockerignore                                          0.1s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/library/python:3.8-slim         0.0s
#  => [1/5] FROM docker.io/library/python:3.8-slim                           0.0s
#  => [internal] load build context                                          4.4s
#  => => transferring context: 35.30MB                                       2.5s
# [+] Building 4.8s (4/9)
#  => [internal] load build definition from Dockerfile                       0.1s
#  => => transferring dockerfile: 247B                                       0.1s
#  => [internal] load .dockerignore                                          0.1s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/library/python:3.8-slim         0.0s
#  => [1/5] FROM docker.io/library/python:3.8-slim                           0.0s
#  => [internal] load build context                                          4.5s
#  => => transferring context: 39.17MB                                       2.6s
# [+] Building 4.9s (4/9)
#  => [internal] load build definition from Dockerfile                       0.1s
#  => => transferring dockerfile: 247B                                       0.1s
#  => [internal] load .dockerignore                                          0.1s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/library/python:3.8-slim         0.0s
#  => [1/5] FROM docker.io/library/python:3.8-slim                           0.0s
#  => [internal] load build context                                          4.6s
#  => => transferring context: 40.45MB                                       2.7s
# [+] Building 5.1s (4/9)
#  => [internal] load build definition from Dockerfile                       0.1s
#  => => transferring dockerfile: 247B                                       0.1s
#  => [internal] load .dockerignore                                          0.1s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/library/python:3.8-slim         0.0s
#  => [1/5] FROM docker.io/library/python:3.8-slim                           0.0s
#  => [internal] load build context                                          4.8s
#  => => transferring context: 41.50MB                                       2.9s
# [+] Building 5.2s (4/9)
#  => [internal] load build definition from Dockerfile                       0.1s
#  => => transferring dockerfile: 247B                                       0.1s
#  => [internal] load .dockerignore                                          0.1s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/library/python:3.8-slim         0.0s
#  => [1/5] FROM docker.io/library/python:3.8-slim                           0.0s
#  => [internal] load build context                                          4.9s
#  => => transferring context: 45.69MB                                       3.0s
# [+] Building 5.3s (4/9)
#  => [internal] load build definition from Dockerfile                       0.1s
#  => => transferring dockerfile: 247B                                       0.1s
#  => [internal] load .dockerignore                                          0.1s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/library/python:3.8-slim         0.0s
#  => [1/5] FROM docker.io/library/python:3.8-slim                           0.0s
#  => [internal] load build context                                          5.1s
#  => => transferring context: 49.46MB                                       3.1s
# [+] Building 5.5s (4/9)
#  => [internal] load build definition from Dockerfile                       0.1s
#  => => transferring dockerfile: 247B                                       0.1s
#  => [internal] load .dockerignore                                          0.1s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/library/python:3.8-slim         0.0s
#  => [1/5] FROM docker.io/library/python:3.8-slim                           0.0s
#  => [internal] load build context                                          5.2s
#  => => transferring context: 55.23MB                                       3.3s
# [+] Building 5.6s (4/9)
#  => [internal] load build definition from Dockerfile                       0.1s
#  => => transferring dockerfile: 247B                                       0.1s
#  => [internal] load .dockerignore                                          0.1s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/library/python:3.8-slim         0.0s
#  => [1/5] FROM docker.io/library/python:3.8-slim                           0.0s
#  => [internal] load build context                                          5.3s
#  => => transferring context: 55.99MB                                       3.4s
# [+] Building 5.7s (4/9)
#  => [internal] load build definition from Dockerfile                       0.1s
#  => => transferring dockerfile: 247B                                       0.1s
#  => [internal] load .dockerignore                                          0.1s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/library/python:3.8-slim         0.0s
#  => [1/5] FROM docker.io/library/python:3.8-slim                           0.0s
#  => [internal] load build context                                          5.4s
#  => => transferring context: 58.05MB                                       3.5s
# [+] Building 5.9s (4/9)
#  => [internal] load build definition from Dockerfile                       0.1s
#  => => transferring dockerfile: 247B                                       0.1s
#  => [internal] load .dockerignore                                          0.1s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/library/python:3.8-slim         0.0s
#  => [1/5] FROM docker.io/library/python:3.8-slim                           0.0s
#  => [internal] load build context                                          5.6s
#  => => transferring context: 60.84MB                                       3.7s
# [+] Building 6.0s (4/9)
#  => [internal] load build definition from Dockerfile                       0.1s
#  => => transferring dockerfile: 247B                                       0.1s
#  => [internal] load .dockerignore                                          0.1s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/library/python:3.8-slim         0.0s
#  => [1/5] FROM docker.io/library/python:3.8-slim                           0.0s
#  => [internal] load build context                                          5.7s
#  => => transferring context: 68.99MB                                       3.8s
# [+] Building 6.1s (4/9)
#  => [internal] load build definition from Dockerfile                       0.1s
#  => => transferring dockerfile: 247B                                       0.1s
#  => [internal] load .dockerignore                                          0.1s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/library/python:3.8-slim         0.0s
#  => [1/5] FROM docker.io/library/python:3.8-slim                           0.0s
#  => [internal] load build context                                          5.9s
#  => => transferring context: 73.22MB                                       3.9s
# [+] Building 6.3s (4/9)
#  => [internal] load build definition from Dockerfile                       0.1s
#  => => transferring dockerfile: 247B                                       0.1s
#  => [internal] load .dockerignore                                          0.1s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/library/python:3.8-slim         0.0s
#  => [1/5] FROM docker.io/library/python:3.8-slim                           0.0s
#  => [internal] load build context                                          6.0s
#  => => transferring context: 75.95MB                                       4.1s
# ^C
# [+] Building 6.5s (4/9)
#  => [internal] load build definition from Dockerfile                       0.1s
#  => => transferring dockerfile: 247B                                       0.1s
#  => [internal] load .dockerignore                                          0.1s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/library/python:3.8-slim         0.0s
#  => [1/5] FROM docker.io/library/python:3.8-slim                           0.0s
#  => [internal] load build context                                          6.3s
#  => => transferring context: 83.36MB                                       4.3s
# [+] Building 6.7s (4/9)
#  => [internal] load build definition from Dockerfile                       0.1s
#  => => transferring dockerfile: 247B                                       0.1s
#  => [internal] load .dockerignore                                          0.1s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/library/python:3.8-slim         0.0s
#  => [1/5] FROM docker.io/library/python:3.8-slim                           0.0s
#  => [internal] load build context                                          6.4s
#  => => transferring context: 83.89MB                                       4.4s
# Process LokyProcess-37:
# Process LokyProcess-39:
# Process LokyProcess-42:
# Process LokyProcess-43:
# Process LokyProcess-45:
# Process LokyProcess-48:
# Process LokyProcess-44:
# Process LokyProcess-40:
# Process LokyProcess-47:
# Process LokyProcess-38:
# Error in atexit._run_exitfuncs:
# Traceback (most recent call last):
#   File "/Users/gerzsonboros/miniconda3/lib/python3.8/concurrent/futures/process.py", line 100, in _python_exit
#     items = list(_threads_wakeups.items())
#   File "/Users/gerzsonboros/miniconda3/lib/python3.8/weakref.py", line 434, in items
#     yield key, value
#   File "/Users/gerzsonboros/miniconda3/lib/python3.8/_weakrefset.py", line 26, in __exit__
#     def __exit__(self, e, t, b):
# KeyboardInterrupt
# Exception ignored in: <module 'threading' from '/Users/gerzsonboros/miniconda3/lib/python3.8/threading.py'>
# Traceback (most recent call last):
#   File "/Users/gerzsonboros/miniconda3/lib/python3.8/threading.py", line 1355, in _shutdown
#     def _shutdown():
# KeyboardInterrupt:
# Exception ignored in: <module 'threading' from '/Users/gerzsonboros/miniconda3/lib/python3.8/threading.py'>
# Traceback (most recent call last):
#   File "/Users/gerzsonboros/miniconda3/lib/python3.8/threading.py", line 1355, in _shutdown
#     def _shutdown():
# KeyboardInterrupt:
# Exception ignored in: <module 'threading' from '/Users/gerzsonboros/miniconda3/lib/python3.8/threading.py'>
# Traceback (most recent call last):
#   File "/Users/gerzsonboros/miniconda3/lib/python3.8/threading.py", line 1355, in _shutdown
#     def _shutdown():
# KeyboardInterrupt:
# Process LokyProcess-46:
# Exception ignored in: <module 'threading' from '/Users/gerzsonboros/miniconda3/lib/python3.8/threading.py'>
# Traceback (most recent call last):
#   File "/Users/gerzsonboros/miniconda3/lib/python3.8/threading.py", line 1373, in _shutdown
#     assert tlock.locked()
# AssertionError:
# Exception ignored in: <module 'threading' from '/Users/gerzsonboros/miniconda3/lib/python3.8/threading.py'>
# Traceback (most recent call last):
#   File "/Users/gerzsonboros/miniconda3/lib/python3.8/threading.py", line 1355, in _shutdown
#     def _shutdown():
# KeyboardInterrupt:
# Exception ignored in: <module 'threading' from '/Users/gerzsonboros/miniconda3/lib/python3.8/threading.py'>
# Traceback (most recent call last):
#   File "/Users/gerzsonboros/miniconda3/lib/python3.8/threading.py", line 1355, in _shutdown
#     def _shutdown():
# KeyboardInterrupt:
# Exception ignored in: <module 'threading' from '/Users/gerzsonboros/miniconda3/lib/python3.8/threading.py'>
# Traceback (most recent call last):
#   File "/Users/gerzsonboros/miniconda3/lib/python3.8/threading.py", line 1355, in _shutdown
# KeyboardInterrupt:
# Error in atexit._run_exitfuncs:
# Traceback (most recent call last):
#   File "/Users/gerzsonboros/miniconda3/lib/python3.8/concurrent/futures/process.py", line 97, in _python_exit
#     def _python_exit():
# KeyboardInterrupt
# Process LokyProcess-41:
# Error in atexit._run_exitfuncs:
# Traceback (most recent call last):
#   File "/Users/gerzsonboros/miniconda3/lib/python3.8/concurrent/futures/process.py", line 97, in _python_exit
#     def _python_exit():
# KeyboardInterrupt
# Error in atexit._run_exitfuncs:
# Traceback (most recent call last):
#   File "/Users/gerzsonboros/miniconda3/lib/python3.8/concurrent/futures/process.py", line 100, in _python_exit
#     items = list(_threads_wakeups.items())
#   File "/Users/gerzsonboros/miniconda3/lib/python3.8/weakref.py", line 430, in items
#     with _IterationGuard(self):
#   File "/Users/gerzsonboros/miniconda3/lib/python3.8/_weakrefset.py", line 23, in __enter__
#     w._iterating.add(self)
# KeyboardInterrupt
# Error in atexit._run_exitfuncs:
# Traceback (most recent call last):
#   File "/Users/gerzsonboros/miniconda3/lib/python3.8/multiprocessing/util.py", line 334, in _exit_function
#     _run_finalizers(0)
#   File "/Users/gerzsonboros/miniconda3/lib/python3.8/multiprocessing/util.py", line 292, in _run_finalizers
#     keys.sort(reverse=True)
# KeyboardInterrupt
# Error in atexit._run_exitfuncs:
# Traceback (most recent call last):
#   File "/Users/gerzsonboros/miniconda3/lib/python3.8/concurrent/futures/process.py", line 100, in _python_exit
#     items = list(_threads_wakeups.items())
#   File "/Users/gerzsonboros/miniconda3/lib/python3.8/weakref.py", line 430, in items
#     with _IterationGuard(self):
#   File "/Users/gerzsonboros/miniconda3/lib/python3.8/_weakrefset.py", line 18, in __init__
#     self.weakcontainer = ref(weakcontainer)
# KeyboardInterrupt
# Error in atexit._run_exitfuncs:
# Traceback (most recent call last):
#   File "/Users/gerzsonboros/miniconda3/lib/python3.8/concurrent/futures/process.py", line 100, in _python_exit
#     items = list(_threads_wakeups.items())
#   File "/Users/gerzsonboros/miniconda3/lib/python3.8/weakref.py", line 430, in items
#     with _IterationGuard(self):
#   File "/Users/gerzsonboros/miniconda3/lib/python3.8/_weakrefset.py", line 18, in __init__
#     self.weakcontainer = ref(weakcontainer)
# KeyboardInterrupt

# %%
# !docker run -d -p 8007:8007 fraud_voting_model_api_with_get_for_docker3
# Out:
# 687fc5d2f11bffaebb9044b773fe908a395d173975f1db811a3e000ceb803fbd
# docker: Error response from daemon: driver failed programming external connectivity on endpoint practical_chaum (04c03a715fa493d98e09aeec4d624c6384cc20fa4cb89215a5495bd7eec44089): Bind for 0.0.0.0:8005 failed: port is already allocated.

# %%
# !docker images
# Out:
# REPOSITORY                                          TAG        IMAGE ID       CREATED         SIZE
# fraud_voting_model_api_with_get_for_docker2_image   latest     842a1bcc3892   5 minutes ago   2.17GB
# fraud_voting_model_api_with_get_for_docker          latest     4b18ba7e373b   15 hours ago    2.16GB
# fraud_voting_model_api                              latest     e3d11ce18018   16 hours ago    2.16GB
# churn_voting_model_api                              latest     98ee34619e84   2 days ago      8.51GB
# <none>                                              <none>     9d4d6d2d6b64   2 weeks ago     7.98GB
# python                                              3.8-slim   d069e16584a2   2 weeks ago     123MB
# gradflow/workbench/jupyter                          0.1.0      8cc8d764d69d   5 weeks ago     4.49GB
# gradflow/workbench/mlflow                           0.1.0      002ae258879f   5 weeks ago     1.2GB
# gradflow/workbench/postgres                         0.1.0      52c64288b248   5 weeks ago     314MB
# <none>                                              <none>     813c7f4c4e3d   2 months ago    4.4GB
# docker101tutorial                                   latest     59a4f1fb6fe4   2 months ago    29.8MB
# postgres                                            13         6c9d9a36455e   2 months ago    373MB
# redis                                               latest     3e12e2ceb68f   2 months ago    117MB
# alpine/git                                          latest     22d84a66cda4   3 months ago    43.6MB
# apache/airflow                                      2.4.2      f4ca517e02e4   4 months ago    1.14GB

# %%
import json
url = 'http://127.0.0.1:8007/get_predict/'

params = json.loads(df_test.loc[df_test.target == 1].iloc[0].to_json())
response = requests.get(url, params).json()
print(response)
